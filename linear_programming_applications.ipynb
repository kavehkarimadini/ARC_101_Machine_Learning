# %% [markdown]
# <a href="https://colab.research.google.com/github/kavehkarimadini/ARC_101_Machine_Learning/blob/main/linear_programming_applications.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pulp import *
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px

# %% [markdown]
# # The problems we solved with Linear Programing in this notebook
#
# *  Equations LP and Visualisation
# * Resources Allocation
#     - Farmer's problem 👩‍🌾
# * Knapsack problem 🎒🪙
# * SUDUKO

# %% [markdown]
# ![image.png](attachment:de3c6a53-1b5f-46c8-a1bf-0dd7112a014c.png)

# %%
# Construct lines
# x > 0
x = np.linspace(0, 20, 2000)
# y >= 2
y1 = (x*0) + 2
# 2y <= 25 - x
y2 = (25-x)/2.0
# 4y >= 2x - 8
y3 = (2*x-8)/4.0
# y <= 2x - 5
y4 = 2 * x -5

# Make plot
plt.figure(figsize=(10,7))
# Plot the objective function
plt.plot(x, y1, label=r'$2x + y \leq 20$')
plt.plot(x, y2, label=r'$4x - 5y \geq -10$')
plt.plot(x, y3, label=r'$x + 2y \leq 12$')
plt.plot(x, y4,  label=r'$y \geq 2$')
plt.xlim((0, 16))
plt.ylim((0, 11))
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
# Fill feasible region
y5 = np.minimum(y2, y4) # 🟠🔴 (min⬇️)
y6 = np.maximum(y1, y3) # 🔵🟢 (max⬆️)
plt.fill_between(x, y5, y6, where=y5>y6, color='skyblue')
plt.legend()
# plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# Create a LP problem
lp_problem = LpProblem("LP_Problem", LpMaximize)

# %%
# Define decision variables
x = LpVariable("x", lowBound=0, cat="Continuous")
y = LpVariable("y", lowBound=2, cat="Continuous")  # y >= 2

# %%
# Define the objective function
lp_problem += 4 * x + 3 * y, "Z"

# %%
# Define constraints
lp_problem += 2 * y <= 25 - x, "Constraint1"
lp_problem += 4 * y >= 2 * x - 8, "Constraint2"
lp_problem += y <= 2 * x - 5, "Constraint3"

# %%
lp_problem
# Out:
# LP_Problem:
# MAXIMIZE
# 4*x + 3*y + 0
# SUBJECT TO
# Constraint1: x + 2 y <= 25
#
# Constraint2: - 2 x + 4 y >= -8
#
# Constraint3: - 2 x + y <= -5
#
# VARIABLES
# x Continuous
# 2 <= y Continuous

# %%
# Solve the LP problem
lp_problem.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b2ede6320edc4474859f42ac781b4f07-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b2ede6320edc4474859f42ac781b4f07-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 17 RHS
# At line 21 BOUNDS
# At line 23 ENDATA
# Problem MODEL has 3 rows, 2 columns and 6 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 3 (0) rows, 2 (0) columns and 6 (0) elements
# 0  Obj 6 Primal inf 3.4999999 (1) Dual inf 6.9999998 (2)
# 0  Obj 6 Primal inf 3.4999999 (1) Dual inf 1e+10 (1)
# 2  Obj 73.75
# Optimal - objective value 73.75
# Optimal objective 73.75 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
# 1

# %%
# Print the results
print("Status:", LpStatus[lp_problem.status])
print("Optimal value for x:", value(x))
print("Optimal value for y:", value(y))
print("Optimal objective function value (Z):", value(lp_problem.objective))

optimal_x = value(x)
optimal_y = value(y)
optimal_obj = value(lp_problem.objective)
# Out:
# Status: Optimal
# Optimal value for x: 14.5
# Optimal value for y: 5.25
# Optimal objective function value (Z): 73.75

# %%
lp_problem
# Out:
# LP_Problem:
# MAXIMIZE
# 4*x + 3*y + 0
# SUBJECT TO
# Constraint1: x + 2 y <= 25
#
# Constraint2: - 2 x + 4 y >= -8
#
# Constraint3: - 2 x + y <= -5
#
# VARIABLES
# x Continuous
# 2 <= y Continuous

# %%
# Construct lines
# x > 0
x = np.linspace(0, 20, 2000)
# y >= 2
y1 = (x*0) + 2
# 2y <= 25 - x
y2 = (25-x)/2.0
# 4y >= 2x - 8
y3 = (2*x-8)/4.0
# y <= 2x - 5
y4 = 2 * x -5
# objective
obj = (73.75 - 4*x)/3

# Make plot
plt.figure(figsize=(10,7))
# Plot the objective function
plt.plot(x, y1, label=r'$y \geq 2$')
plt.plot(x, y2, label=r'$2y \geq 25 - x$')
plt.plot(x, y3, label=r'$4y \geq 2x - 8$')
plt.plot(x, y4,  label=r'$y \leq 2x-5$')
# plt.plot(x, obj, label="$objective = \\frac{73.75 - 4x}{3}$")
plt.scatter(optimal_x, optimal_y, color="red", marker="o", s=300, label=f'Optimal Point {optimal_x, optimal_y}')
plt.xlim((0, 16))
plt.ylim((0, 11))
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
# Fill feasible region
y5 = np.minimum(y2, y4) # 🟠🔴 (min⬇️)
y6 = np.maximum(y1, y3) # 🔵🟢 (max⬆️)
plt.fill_between(x, y5, y6, where=y5>y6, color='skyblue', alpha=0.5)
plt.legend()
plt.show()

# %% [markdown]
# # Applications

# %% [markdown]
# ## Farmer’s problem

# %% [markdown]
# With the planting season steadily approaching, your farmer friend presents you with the following problem.
#
# You have
# - 3 tons of potato seeds and
# - 4 tons of carrot seeds.
#
# To grow the crops efficiently, you also have
#
# - 5 tons of fertilizer, which has to be used when planting in a
# 1:1 ratio (i.e. 1 kilogram of potatoes or carrots requires  1 kilogram of fertilizer).
#
# The profit is
# - 1.2$/kg  for potato seeds
# - 1.7$/kg for carrot seeds.
#
# How much potatoes and carrots should you plant to maximize your profit this season?

# %%
model = LpProblem("Farming", LpMaximize)

# variables - how much do we plant?
x_p = LpVariable(name="potatoes", lowBound=0)
x_c = LpVariable(name="carrots", lowBound=0)

# inequalities - don't use more than we have
model += x_p       <= 3000  # potatoes
model +=       x_c <= 4000  # carrots
model += x_p + x_c <= 5000  # fertilizer

# objective function - maximize the profit
model += x_p * 1.2 + x_c * 1.7

# %%
model
# Out:
# Farming:
# MAXIMIZE
# 1.7*carrots + 1.2*potatoes + 0.0
# SUBJECT TO
# _C1: potatoes <= 3000
#
# _C2: carrots <= 4000
#
# _C3: carrots + potatoes <= 5000
#
# VARIABLES
# carrots Continuous
# potatoes Continuous

# %%
status = model.solve()
status
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e46792eceb9c45ef9ab5d7c635ef9c67-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/e46792eceb9c45ef9ab5d7c635ef9c67-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 15 RHS
# At line 19 BOUNDS
# At line 20 ENDATA
# Problem MODEL has 3 rows, 2 columns and 4 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 1 (-2) rows, 2 (0) columns and 2 (-2) elements
# 0  Obj -0 Dual inf 2.899998 (2)
# 1  Obj 8000
# Optimal - objective value 8000
# After Postsolve, objective 8000, infeasibilities - dual 0 (0), primal 0 (0)
# Optimal objective 8000 - 1 iterations time 0.002, Presolve 0.00
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.02
# 1

# %%
print("potatoes:", x_p.value())
print("carrots:", x_c.value())
print("profit:", model.objective.value())
# Out:
# potatoes: 1000.0
# carrots: 4000.0
# profit: 8000.0

# %% [markdown]
# ## Knapsack problem
# ![image.png](attachment:image.png)
# >which books should be chosen to maximize the amount of money while still keeping the overall weight under or equal to 15 kg
# https://en.wikipedia.org/wiki/Knapsack_problem

# %%
# Example data (values, weights, and capacity)
values = [10, 4, 8, 5, 3]
weights = [5, 2, 8, 3, 1]
capacity = 10

# Create a binary variable for each item
items = range(len(values))
x = LpVariable.dicts("item", items, cat="Binary")

x
# Out:
# {0: item_0, 1: item_1, 2: item_2, 3: item_3, 4: item_4}

# %%
# Create the knapsack problem as an LP problem
knapsack_problem = LpProblem("Knapsack", LpMaximize)

# %%
# Objective function: Maximize the total value
knapsack_problem += lpSum([values[i] * x[i] for i in items])

# Constraint: Total weight must not exceed the capacity
knapsack_problem += lpSum([weights[i] * x[i] for i in items]) <= capacity

# %%
knapsack_problem
'''
Maximize W*ITEMS
Subject to
        ∑(W*ITEMS) <= 10 (Capacity)
Variables
is whether this item is selected or no
'''
# Out:
# '\nMaximize W*ITEMS\nSubject to \n        ∑(W*ITEMS) <= 10 (Capacity)\nVariables \nis whether this item is selected or no\n'

# %%
print(x)
# for example is this x item selected
print(x[1].value())
# for example is this x item selected
print(x[2].value())
# Out:
# {0: item_0, 1: item_1, 2: item_2, 3: item_3, 4: item_4}
# None
# None

# %%
# Solve the problem
knapsack_problem.solve()

# Print the results
print("Status:", knapsack_problem.status)
print("Total value:", lpSum([values[i] * x[i].value() for i in items]))
print("Total Weight:", lpSum([weights[i] * x[i].value() for i in items]))
print("Selected items:")
for i in items:
    # if this item is selected
    if x[i].value() == 1:
        print(f"Item {i + 1}: Value={values[i]}, Weight={weights[i]}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b0c8da74ab6d4c64bfdcf0aa854f96ec-pulp.mps max timeMode elapsed branch printingOptions all solution /tmp/b0c8da74ab6d4c64bfdcf0aa854f96ec-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 6 COLUMNS
# At line 27 RHS
# At line 29 BOUNDS
# At line 35 ENDATA
# Problem MODEL has 1 rows, 5 columns and 5 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 20.3333 - 0.00 seconds
# Cgl0004I processed model has 1 rows, 5 columns (5 integer (5 of which binary)) and 5 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.333333
# Cbc0038I Pass   1: suminf.    0.20000 (1) obj. -20 iterations 1
# Cbc0038I Solution found of -12
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 5 columns, reduced to 1 rows 2 columns
# Cbc0038I Mini branch and bound improved solution from -12 to -17 (0.01 seconds)
# Cbc0038I Round again with cutoff of -18.2332
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 2
# Cbc0038I Pass   2: suminf.    0.20000 (1) obj. -20 iterations 0
# Cbc0038I Pass   3: suminf.    0.37668 (1) obj. -18.2332 iterations 1
# Cbc0038I Pass   4: suminf.    0.20000 (1) obj. -20 iterations 1
# Cbc0038I Pass   5: suminf.    0.37668 (1) obj. -18.2332 iterations 1
# Cbc0038I Pass   6: suminf.    0.24665 (1) obj. -18.2332 iterations 1
# Cbc0038I Pass   7: suminf.    0.24665 (1) obj. -18.2332 iterations 0
# Cbc0038I Pass   8: suminf.    0.24665 (1) obj. -18.2332 iterations 0
# Cbc0038I Pass   9: suminf.    0.24665 (1) obj. -18.2332 iterations 0
# Cbc0038I Pass  10: suminf.    0.05831 (1) obj. -18.2332 iterations 1
# Cbc0038I Pass  11: suminf.    0.05831 (1) obj. -18.2332 iterations 0
# Cbc0038I Pass  12: suminf.    0.20000 (1) obj. -20 iterations 2
# Cbc0038I Pass  13: suminf.    0.00000 (0) obj. -19 iterations 1
# Cbc0038I Solution found of -19
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1 rows 5 columns, reduced to 1 rows 4 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -20.0666
# Cbc0038I Reduced cost fixing fixed 4 variables on major pass 3
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -19 - took 0.00 seconds
# Cbc0012I Integer solution of -19 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 1 rows 5 columns, reduced to 0 rows 0 columns
# Cbc0001I Search completed - best objective -19, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 4 variables fixed on reduced cost
# Cuts at root node changed objective from -20.3333 to -17
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                19.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Status: 1
# Total value: 19.0
# Total Weight: 10.0
# Selected items:
# Item 1: Value=10, Weight=5
# Item 2: Value=4, Weight=2
# Item 4: Value=5, Weight=3

# %% [markdown]
# ## SUDOKU

# %%
# All rows, columns and values within a Sudoku take values from 1 to 9
VALS = ROWS = COLS = range(1, 10)

# %%
# The boxes list is created, with the row and column index of each square in each box
Boxes = [
    [(3 * i + k + 1, 3 * j + l + 1) for k in range(3) for l in range(3)]
    for i in range(3)
    for j in range(3)
]
Boxes
# Out:
# [[(1, 1), (1, 2), (1, 3), (2, 1), (2, 2), (2, 3), (3, 1), (3, 2), (3, 3)],
#  [(1, 4), (1, 5), (1, 6), (2, 4), (2, 5), (2, 6), (3, 4), (3, 5), (3, 6)],
#  [(1, 7), (1, 8), (1, 9), (2, 7), (2, 8), (2, 9), (3, 7), (3, 8), (3, 9)],
#  [(4, 1), (4, 2), (4, 3), (5, 1), (5, 2), (5, 3), (6, 1), (6, 2), (6, 3)],
#  [(4, 4), (4, 5), (4, 6), (5, 4), (5, 5), (5, 6), (6, 4), (6, 5), (6, 6)],
#  [(4, 7), (4, 8), (4, 9), (5, 7), (5, 8), (5, 9), (6, 7), (6, 8), (6, 9)],
#  [(7, 1), (7, 2), (7, 3), (8, 1), (8, 2), (8, 3), (9, 1), (9, 2), (9, 3)],
#  [(7, 4), (7, 5), (7, 6), (8, 4), (8, 5), (8, 6), (9, 4), (9, 5), (9, 6)],
#  [(7, 7), (7, 8), (7, 9), (8, 7), (8, 8), (8, 9), (9, 7), (9, 8), (9, 9)]]

# %%
# The prob variable is created to contain the problem data
prob = LpProblem("Sudoku_Problem")

# %%
# The decision variables are created
# you can choose (select 0,1) a row or a column that it's value [1,.., 9]
choices = LpVariable.dicts("Choice", (VALS, ROWS, COLS), cat="Binary")

# %%
choices
# Out:
# {1: {1: {1: Choice_1_1_1,
#    2: Choice_1_1_2,
#    3: Choice_1_1_3,
#    4: Choice_1_1_4,
#    5: Choice_1_1_5,
#    6: Choice_1_1_6,
#    7: Choice_1_1_7,
#    8: Choice_1_1_8,
#    9: Choice_1_1_9},
#   2: {1: Choice_1_2_1,
#    2: Choice_1_2_2,
#    3: Choice_1_2_3,
#    4: Choice_1_2_4,
#    5: Choice_1_2_5,
#    6: Choice_1_2_6,
#    7: Choice_1_2_7,
#    8: Choice_1_2_8,
#    9: Choice_1_2_9},
#   3: {1: Choice_1_3_1,
#    2: Choice_1_3_2,
#    3: Choice_1_3_3,
#    4: Choice_1_3_4,
#    5: Choice_1_3_5,
#    6: Choice_1_3_6,
#    7: Choice_1_3_7,
#    8: Choice_1_3_8,
#    9: Choice_1_3_9},
#   4: {1: Choice_1_4_1,
#    2: Choice_1_4_2,
#    3: Choice_1_4_3,
#    4: Choice_1_4_4,
#    5: Choice_1_4_5,
#    6: Choice_1_4_6,
#    7: Choice_1_4_7,
#    8: Choice_1_4_8,
#    9: Choice_1_4_9},
#   5: {1: Choice_1_5_1,
#    2: Choice_1_5_2,
#    3: Choice_1_5_3,
#    4: Choice_1_5_4,
#    5: Choice_1_5_5,
#    6: Choice_1_5_6,
#    7: Choice_1_5_7,
#    8: Choice_1_5_8,
#    9: Choice_1_5_9},
#   6: {1: Choice_1_6_1,
#    2: Choice_1_6_2,
#    3: Choice_1_6_3,
#    4: Choice_1_6_4,
#    5: Choice_1_6_5,
#    6: Choice_1_6_6,
#    7: Choice_1_6_7,
#    8: Choice_1_6_8,
#    9: Choice_1_6_9},
#   7: {1: Choice_1_7_1,
#    2: Choice_1_7_2,
#    3: Choice_1_7_3,
#    4: Choice_1_7_4,
#    5: Choice_1_7_5,
#    6: Choice_1_7_6,
#    7: Choice_1_7_7,
#    8: Choice_1_7_8,
#    9: Choice_1_7_9},
#   8: {1: Choice_1_8_1,
#    2: Choice_1_8_2,
#    3: Choice_1_8_3,
#    4: Choice_1_8_4,
#    5: Choice_1_8_5,
#    6: Choice_1_8_6,
#    7: Choice_1_8_7,
#    8: Choice_1_8_8,
#    9: Choice_1_8_9},
#   9: {1: Choice_1_9_1,
#    2: Choice_1_9_2,
#    3: Choice_1_9_3,
#    4: Choice_1_9_4,
#    5: Choice_1_9_5,
#    6: Choice_1_9_6,
#    7: Choice_1_9_7,
#    8: Choice_1_9_8,
#    9: Choice_1_9_9}},
#  2: {1: {1: Choice_2_1_1,
#    2: Choice_2_1_2,
#    3: Choice_2_1_3,
#    4: Choice_2_1_4,
#    5: Choice_2_1_5,
#    6: Choice_2_1_6,
#    7: Choice_2_1_7,
#    8: Choice_2_1_8,
#    9: Choice_2_1_9},
#   2: {1: Choice_2_2_1,
#    2: Choice_2_2_2,
#    3: Choice_2_2_3,
#    4: Choice_2_2_4,
#    5: Choice_2_2_5,
#    6: Choice_2_2_6,
#    7: Choice_2_2_7,
#    8: Choice_2_2_8,
#    9: Choice_2_2_9},
#   3: {1: Choice_2_3_1,
#    2: Choice_2_3_2,
#    3: Choice_2_3_3,
#    4: Choice_2_3_4,
#    5: Choice_2_3_5,
#    6: Choice_2_3_6,
#    7: Choice_2_3_7,
#    8: Choice_2_3_8,
#    9: Choice_2_3_9},
#   4: {1: Choice_2_4_1,
#    2: Choice_2_4_2,
#    3: Choice_2_4_3,
#    4: Choice_2_4_4,
#    5: Choice_2_4_5,
#    6: Choice_2_4_6,
#    7: Choice_2_4_7,
#    8: Choice_2_4_8,
#    9: Choice_2_4_9},
#   5: {1: Choice_2_5_1,
#    2: Choice_2_5_2,
#    3: Choice_2_5_3,
#    4: Choice_2_5_4,
#    5: Choice_2_5_5,
#    6: Choice_2_5_6,
#    7: Choice_2_5_7,
#    8: Choice_2_5_8,
#    9: Choice_2_5_9},
#   6: {1: Choice_2_6_1,
#    2: Choice_2_6_2,
#    3: Choice_2_6_3,
#    4: Choice_2_6_4,
#    5: Choice_2_6_5,
#    6: Choice_2_6_6,
#    7: Choice_2_6_7,
#    8: Choice_2_6_8,
#    9: Choice_2_6_9},
#   7: {1: Choice_2_7_1,
#    2: Choice_2_7_2,
#    3: Choice_2_7_3,
#    4: Choice_2_7_4,
#    5: Choice_2_7_5,
#    6: Choice_2_7_6,
#    7: Choice_2_7_7,
#    8: Choice_2_7_8,
#    9: Choice_2_7_9},
#   8: {1: Choice_2_8_1,
#    2: Choice_2_8_2,
#    3: Choice_2_8_3,
#    4: Choice_2_8_4,
#    5: Choice_2_8_5,
#    6: Choice_2_8_6,
#    7: Choice_2_8_7,
#    8: Choice_2_8_8,
#    9: Choice_2_8_9},
#   9: {1: Choice_2_9_1,
#    2: Choice_2_9_2,
#    3: Choice_2_9_3,
#    4: Choice_2_9_4,
#    5: Choice_2_9_5,
#    6: Choice_2_9_6,
#    7: Choice_2_9_7,
#    8: Choice_2_9_8,
#    9: Choice_2_9_9}},
#  3: {1: {1: Choice_3_1_1,
#    2: Choice_3_1_2,
#    3: Choice_3_1_3,
#    4: Choice_3_1_4,
#    5: Choice_3_1_5,
#    6: Choice_3_1_6,
#    7: Choice_3_1_7,
#    8: Choice_3_1_8,
#    9: Choice_3_1_9},
#   2: {1: Choice_3_2_1,
#    2: Choice_3_2_2,
#    3: Choice_3_2_3,
#    4: Choice_3_2_4,
#    5: Choice_3_2_5,
#    6: Choice_3_2_6,
#    7: Choice_3_2_7,
#    8: Choice_3_2_8,
#    9: Choice_3_2_9},
#   3: {1: Choice_3_3_1,
#    2: Choice_3_3_2,
#    3: Choice_3_3_3,
#    4: Choice_3_3_4,
#    5: Choice_3_3_5,
#    6: Choice_3_3_6,
#    7: Choice_3_3_7,
#    8: Choice_3_3_8,
#    9: Choice_3_3_9},
#   4: {1: Choice_3_4_1,
#    2: Choice_3_4_2,
#    3: Choice_3_4_3,
#    4: Choice_3_4_4,
#    5: Choice_3_4_5,
#    6: Choice_3_4_6,
#    7: Choice_3_4_7,
#    8: Choice_3_4_8,
#    9: Choice_3_4_9},
#   5: {1: Choice_3_5_1,
#    2: Choice_3_5_2,
#    3: Choice_3_5_3,
#    4: Choice_3_5_4,
#    5: Choice_3_5_5,
#    6: Choice_3_5_6,
#    7: Choice_3_5_7,
#    8: Choice_3_5_8,
#    9: Choice_3_5_9},
#   6: {1: Choice_3_6_1,
#    2: Choice_3_6_2,
#    3: Choice_3_6_3,
#    4: Choice_3_6_4,
#    5: Choice_3_6_5,
#    6: Choice_3_6_6,
#    7: Choice_3_6_7,
#    8: Choice_3_6_8,
#    9: Choice_3_6_9},
#   7: {1: Choice_3_7_1,
#    2: Choice_3_7_2,
#    3: Choice_3_7_3,
#    4: Choice_3_7_4,
#    5: Choice_3_7_5,
#    6: Choice_3_7_6,
#    7: Choice_3_7_7,
#    8: Choice_3_7_8,
#    9: Choice_3_7_9},
#   8: {1: Choice_3_8_1,
#    2: Choice_3_8_2,
#    3: Choice_3_8_3,
#    4: Choice_3_8_4,
#    5: Choice_3_8_5,
#    6: Choice_3_8_6,
#    7: Choice_3_8_7,
#    8: Choice_3_8_8,
#    9: Choice_3_8_9},
#   9: {1: Choice_3_9_1,
#    2: Choice_3_9_2,
#    3: Choice_3_9_3,
#    4: Choice_3_9_4,
#    5: Choice_3_9_5,
#    6: Choice_3_9_6,
#    7: Choice_3_9_7,
#    8: Choice_3_9_8,
#    9: Choice_3_9_9}},
#  4: {1: {1: Choice_4_1_1,
#    2: Choice_4_1_2,
#    3: Choice_4_1_3,
#    4: Choice_4_1_4,
#    5: Choice_4_1_5,
#    6: Choice_4_1_6,
#    7: Choice_4_1_7,
#    8: Choice_4_1_8,
#    9: Choice_4_1_9},
#   2: {1: Choice_4_2_1,
#    2: Choice_4_2_2,
#    3: Choice_4_2_3,
#    4: Choice_4_2_4,
#    5: Choice_4_2_5,
#    6: Choice_4_2_6,
#    7: Choice_4_2_7,
#    8: Choice_4_2_8,
#    9: Choice_4_2_9},
#   3: {1: Choice_4_3_1,
#    2: Choice_4_3_2,
#    3: Choice_4_3_3,
#    4: Choice_4_3_4,
#    5: Choice_4_3_5,
#    6: Choice_4_3_6,
#    7: Choice_4_3_7,
#    8: Choice_4_3_8,
#    9: Choice_4_3_9},
#   4: {1: Choice_4_4_1,
#    2: Choice_4_4_2,
#    3: Choice_4_4_3,
#    4: Choice_4_4_4,
#    5: Choice_4_4_5,
#    6: Choice_4_4_6,
#    7: Choice_4_4_7,
#    8: Choice_4_4_8,
#    9: Choice_4_4_9},
#   5: {1: Choice_4_5_1,
#    2: Choice_4_5_2,
#    3: Choice_4_5_3,
#    4: Choice_4_5_4,
#    5: Choice_4_5_5,
#    6: Choice_4_5_6,
#    7: Choice_4_5_7,
#    8: Choice_4_5_8,
#    9: Choice_4_5_9},
#   6: {1: Choice_4_6_1,
#    2: Choice_4_6_2,
#    3: Choice_4_6_3,
#    4: Choice_4_6_4,
#    5: Choice_4_6_5,
#    6: Choice_4_6_6,
#    7: Choice_4_6_7,
#    8: Choice_4_6_8,
#    9: Choice_4_6_9},
#   7: {1: Choice_4_7_1,
#    2: Choice_4_7_2,
#    3: Choice_4_7_3,
#    4: Choice_4_7_4,
#    5: Choice_4_7_5,
#    6: Choice_4_7_6,
#    7: Choice_4_7_7,
#    8: Choice_4_7_8,
#    9: Choice_4_7_9},
#   8: {1: Choice_4_8_1,
#    2: Choice_4_8_2,
#    3: Choice_4_8_3,
#    4: Choice_4_8_4,
#    5: Choice_4_8_5,
#    6: Choice_4_8_6,
#    7: Choice_4_8_7,
#    8: Choice_4_8_8,
#    9: Choice_4_8_9},
#   9: {1: Choice_4_9_1,
#    2: Choice_4_9_2,
#    3: Choice_4_9_3,
#    4: Choice_4_9_4,
#    5: Choice_4_9_5,
#    6: Choice_4_9_6,
#    7: Choice_4_9_7,
#    8: Choice_4_9_8,
#    9: Choice_4_9_9}},
#  5: {1: {1: Choice_5_1_1,
#    2: Choice_5_1_2,
#    3: Choice_5_1_3,
#    4: Choice_5_1_4,
#    5: Choice_5_1_5,
#    6: Choice_5_1_6,
#    7: Choice_5_1_7,
#    8: Choice_5_1_8,
#    9: Choice_5_1_9},
#   2: {1: Choice_5_2_1,
#    2: Choice_5_2_2,
#    3: Choice_5_2_3,
#    4: Choice_5_2_4,
#    5: Choice_5_2_5,
#    6: Choice_5_2_6,
#    7: Choice_5_2_7,
#    8: Choice_5_2_8,
#    9: Choice_5_2_9},
#   3: {1: Choice_5_3_1,
#    2: Choice_5_3_2,
#    3: Choice_5_3_3,
#    4: Choice_5_3_4,
#    5: Choice_5_3_5,
#    6: Choice_5_3_6,
#    7: Choice_5_3_7,
#    8: Choice_5_3_8,
#    9: Choice_5_3_9},
#   4: {1: Choice_5_4_1,
#    2: Choice_5_4_2,
#    3: Choice_5_4_3,
#    4: Choice_5_4_4,
#    5: Choice_5_4_5,
#    6: Choice_5_4_6,
#    7: Choice_5_4_7,
#    8: Choice_5_4_8,
#    9: Choice_5_4_9},
#   5: {1: Choice_5_5_1,
#    2: Choice_5_5_2,
#    3: Choice_5_5_3,
#    4: Choice_5_5_4,
#    5: Choice_5_5_5,
#    6: Choice_5_5_6,
#    7: Choice_5_5_7,
#    8: Choice_5_5_8,
#    9: Choice_5_5_9},
#   6: {1: Choice_5_6_1,
#    2: Choice_5_6_2,
#    3: Choice_5_6_3,
#    4: Choice_5_6_4,
#    5: Choice_5_6_5,
#    6: Choice_5_6_6,
#    7: Choice_5_6_7,
#    8: Choice_5_6_8,
#    9: Choice_5_6_9},
#   7: {1: Choice_5_7_1,
#    2: Choice_5_7_2,
#    3: Choice_5_7_3,
#    4: Choice_5_7_4,
#    5: Choice_5_7_5,
#    6: Choice_5_7_6,
#    7: Choice_5_7_7,
#    8: Choice_5_7_8,
#    9: Choice_5_7_9},
#   8: {1: Choice_5_8_1,
#    2: Choice_5_8_2,
#    3: Choice_5_8_3,
#    4: Choice_5_8_4,
#    5: Choice_5_8_5,
#    6: Choice_5_8_6,
#    7: Choice_5_8_7,
#    8: Choice_5_8_8,
#    9: Choice_5_8_9},
#   9: {1: Choice_5_9_1,
#    2: Choice_5_9_2,
#    3: Choice_5_9_3,
#    4: Choice_5_9_4,
#    5: Choice_5_9_5,
#    6: Choice_5_9_6,
#    7: Choice_5_9_7,
#    8: Choice_5_9_8,
#    9: Choice_5_9_9}},
#  6: {1: {1: Choice_6_1_1,
#    2: Choice_6_1_2,
#    3: Choice_6_1_3,
#    4: Choice_6_1_4,
#    5: Choice_6_1_5,
#    6: Choice_6_1_6,
#    7: Choice_6_1_7,
#    8: Choice_6_1_8,
#    9: Choice_6_1_9},
#   2: {1: Choice_6_2_1,
#    2: Choice_6_2_2,
#    3: Choice_6_2_3,
#    4: Choice_6_2_4,
#    5: Choice_6_2_5,
#    6: Choice_6_2_6,
#    7: Choice_6_2_7,
#    8: Choice_6_2_8,
#    9: Choice_6_2_9},
#   3: {1: Choice_6_3_1,
#    2: Choice_6_3_2,
#    3: Choice_6_3_3,
#    4: Choice_6_3_4,
#    5: Choice_6_3_5,
#    6: Choice_6_3_6,
#    7: Choice_6_3_7,
#    8: Choice_6_3_8,
#    9: Choice_6_3_9},
#   4: {1: Choice_6_4_1,
#    2: Choice_6_4_2,
#    3: Choice_6_4_3,
#    4: Choice_6_4_4,
#    5: Choice_6_4_5,
#    6: Choice_6_4_6,
#    7: Choice_6_4_7,
#    8: Choice_6_4_8,
#    9: Choice_6_4_9},
#   5: {1: Choice_6_5_1,
#    2: Choice_6_5_2,
#    3: Choice_6_5_3,
#    4: Choice_6_5_4,
#    5: Choice_6_5_5,
#    6: Choice_6_5_6,
#    7: Choice_6_5_7,
#    8: Choice_6_5_8,
#    9: Choice_6_5_9},
#   6: {1: Choice_6_6_1,
#    2: Choice_6_6_2,
#    3: Choice_6_6_3,
#    4: Choice_6_6_4,
#    5: Choice_6_6_5,
#    6: Choice_6_6_6,
#    7: Choice_6_6_7,
#    8: Choice_6_6_8,
#    9: Choice_6_6_9},
#   7: {1: Choice_6_7_1,
#    2: Choice_6_7_2,
#    3: Choice_6_7_3,
#    4: Choice_6_7_4,
#    5: Choice_6_7_5,
#    6: Choice_6_7_6,
#    7: Choice_6_7_7,
#    8: Choice_6_7_8,
#    9: Choice_6_7_9},
#   8: {1: Choice_6_8_1,
#    2: Choice_6_8_2,
#    3: Choice_6_8_3,
#    4: Choice_6_8_4,
#    5: Choice_6_8_5,
#    6: Choice_6_8_6,
#    7: Choice_6_8_7,
#    8: Choice_6_8_8,
#    9: Choice_6_8_9},
#   9: {1: Choice_6_9_1,
#    2: Choice_6_9_2,
#    3: Choice_6_9_3,
#    4: Choice_6_9_4,
#    5: Choice_6_9_5,
#    6: Choice_6_9_6,
#    7: Choice_6_9_7,
#    8: Choice_6_9_8,
#    9: Choice_6_9_9}},
#  7: {1: {1: Choice_7_1_1,
#    2: Choice_7_1_2,
#    3: Choice_7_1_3,
#    4: Choice_7_1_4,
#    5: Choice_7_1_5,
#    6: Choice_7_1_6,
#    7: Choice_7_1_7,
#    8: Choice_7_1_8,
#    9: Choice_7_1_9},
#   2: {1: Choice_7_2_1,
#    2: Choice_7_2_2,
#    3: Choice_7_2_3,
#    4: Choice_7_2_4,
#    5: Choice_7_2_5,
#    6: Choice_7_2_6,
#    7: Choice_7_2_7,
#    8: Choice_7_2_8,
#    9: Choice_7_2_9},
#   3: {1: Choice_7_3_1,
#    2: Choice_7_3_2,
#    3: Choice_7_3_3,
#    4: Choice_7_3_4,
#    5: Choice_7_3_5,
#    6: Choice_7_3_6,
#    7: Choice_7_3_7,
#    8: Choice_7_3_8,
#    9: Choice_7_3_9},
#   4: {1: Choice_7_4_1,
#    2: Choice_7_4_2,
#    3: Choice_7_4_3,
#    4: Choice_7_4_4,
#    5: Choice_7_4_5,
#    6: Choice_7_4_6,
#    7: Choice_7_4_7,
#    8: Choice_7_4_8,
#    9: Choice_7_4_9},
#   5: {1: Choice_7_5_1,
#    2: Choice_7_5_2,
#    3: Choice_7_5_3,
#    4: Choice_7_5_4,
#    5: Choice_7_5_5,
#    6: Choice_7_5_6,
#    7: Choice_7_5_7,
#    8: Choice_7_5_8,
#    9: Choice_7_5_9},
#   6: {1: Choice_7_6_1,
#    2: Choice_7_6_2,
#    3: Choice_7_6_3,
#    4: Choice_7_6_4,
#    5: Choice_7_6_5,
#    6: Choice_7_6_6,
#    7: Choice_7_6_7,
#    8: Choice_7_6_8,
#    9: Choice_7_6_9},
#   7: {1: Choice_7_7_1,
#    2: Choice_7_7_2,
#    3: Choice_7_7_3,
#    4: Choice_7_7_4,
#    5: Choice_7_7_5,
#    6: Choice_7_7_6,
#    7: Choice_7_7_7,
#    8: Choice_7_7_8,
#    9: Choice_7_7_9},
#   8: {1: Choice_7_8_1,
#    2: Choice_7_8_2,
#    3: Choice_7_8_3,
#    4: Choice_7_8_4,
#    5: Choice_7_8_5,
#    6: Choice_7_8_6,
#    7: Choice_7_8_7,
#    8: Choice_7_8_8,
#    9: Choice_7_8_9},
#   9: {1: Choice_7_9_1,
#    2: Choice_7_9_2,
#    3: Choice_7_9_3,
#    4: Choice_7_9_4,
#    5: Choice_7_9_5,
#    6: Choice_7_9_6,
#    7: Choice_7_9_7,
#    8: Choice_7_9_8,
#    9: Choice_7_9_9}},
#  8: {1: {1: Choice_8_1_1,
#    2: Choice_8_1_2,
#    3: Choice_8_1_3,
#    4: Choice_8_1_4,
#    5: Choice_8_1_5,
#    6: Choice_8_1_6,
#    7: Choice_8_1_7,
#    8: Choice_8_1_8,
#    9: Choice_8_1_9},
#   2: {1: Choice_8_2_1,
#    2: Choice_8_2_2,
#    3: Choice_8_2_3,
#    4: Choice_8_2_4,
#    5: Choice_8_2_5,
#    6: Choice_8_2_6,
#    7: Choice_8_2_7,
#    8: Choice_8_2_8,
#    9: Choice_8_2_9},
#   3: {1: Choice_8_3_1,
#    2: Choice_8_3_2,
#    3: Choice_8_3_3,
#    4: Choice_8_3_4,
#    5: Choice_8_3_5,
#    6: Choice_8_3_6,
#    7: Choice_8_3_7,
#    8: Choice_8_3_8,
#    9: Choice_8_3_9},
#   4: {1: Choice_8_4_1,
#    2: Choice_8_4_2,
#    3: Choice_8_4_3,
#    4: Choice_8_4_4,
#    5: Choice_8_4_5,
#    6: Choice_8_4_6,
#    7: Choice_8_4_7,
#    8: Choice_8_4_8,
#    9: Choice_8_4_9},
#   5: {1: Choice_8_5_1,
#    2: Choice_8_5_2,
#    3: Choice_8_5_3,
#    4: Choice_8_5_4,
#    5: Choice_8_5_5,
#    6: Choice_8_5_6,
#    7: Choice_8_5_7,
#    8: Choice_8_5_8,
#    9: Choice_8_5_9},
#   6: {1: Choice_8_6_1,
#    2: Choice_8_6_2,
#    3: Choice_8_6_3,
#    4: Choice_8_6_4,
#    5: Choice_8_6_5,
#    6: Choice_8_6_6,
#    7: Choice_8_6_7,
#    8: Choice_8_6_8,
#    9: Choice_8_6_9},
#   7: {1: Choice_8_7_1,
#    2: Choice_8_7_2,
#    3: Choice_8_7_3,
#    4: Choice_8_7_4,
#    5: Choice_8_7_5,
#    6: Choice_8_7_6,
#    7: Choice_8_7_7,
#    8: Choice_8_7_8,
#    9: Choice_8_7_9},
#   8: {1: Choice_8_8_1,
#    2: Choice_8_8_2,
#    3: Choice_8_8_3,
#    4: Choice_8_8_4,
#    5: Choice_8_8_5,
#    6: Choice_8_8_6,
#    7: Choice_8_8_7,
#    8: Choice_8_8_8,
#    9: Choice_8_8_9},
#   9: {1: Choice_8_9_1,
#    2: Choice_8_9_2,
#    3: Choice_8_9_3,
#    4: Choice_8_9_4,
#    5: Choice_8_9_5,
#    6: Choice_8_9_6,
#    7: Choice_8_9_7,
#    8: Choice_8_9_8,
#    9: Choice_8_9_9}},
#  9: {1: {1: Choice_9_1_1,
#    2: Choice_9_1_2,
#    3: Choice_9_1_3,
#    4: Choice_9_1_4,
#    5: Choice_9_1_5,
#    6: Choice_9_1_6,
#    7: Choice_9_1_7,
#    8: Choice_9_1_8,
#    9: Choice_9_1_9},
#   2: {1: Choice_9_2_1,
#    2: Choice_9_2_2,
#    3: Choice_9_2_3,
#    4: Choice_9_2_4,
#    5: Choice_9_2_5,
#    6: Choice_9_2_6,
#    7: Choice_9_2_7,
#    8: Choice_9_2_8,
#    9: Choice_9_2_9},
#   3: {1: Choice_9_3_1,
#    2: Choice_9_3_2,
#    3: Choice_9_3_3,
#    4: Choice_9_3_4,
#    5: Choice_9_3_5,
#    6: Choice_9_3_6,
#    7: Choice_9_3_7,
#    8: Choice_9_3_8,
#    9: Choice_9_3_9},
#   4: {1: Choice_9_4_1,
#    2: Choice_9_4_2,
#    3: Choice_9_4_3,
#    4: Choice_9_4_4,
#    5: Choice_9_4_5,
#    6: Choice_9_4_6,
#    7: Choice_9_4_7,
#    8: Choice_9_4_8,
#    9: Choice_9_4_9},
#   5: {1: Choice_9_5_1,
#    2: Choice_9_5_2,
#    3: Choice_9_5_3,
#    4: Choice_9_5_4,
#    5: Choice_9_5_5,
#    6: Choice_9_5_6,
#    7: Choice_9_5_7,
#    8: Choice_9_5_8,
#    9: Choice_9_5_9},
#   6: {1: Choice_9_6_1,
#    2: Choice_9_6_2,
#    3: Choice_9_6_3,
#    4: Choice_9_6_4,
#    5: Choice_9_6_5,
#    6: Choice_9_6_6,
#    7: Choice_9_6_7,
#    8: Choice_9_6_8,
#    9: Choice_9_6_9},
#   7: {1: Choice_9_7_1,
#    2: Choice_9_7_2,
#    3: Choice_9_7_3,
#    4: Choice_9_7_4,
#    5: Choice_9_7_5,
#    6: Choice_9_7_6,
#    7: Choice_9_7_7,
#    8: Choice_9_7_8,
#    9: Choice_9_7_9},
#   8: {1: Choice_9_8_1,
#    2: Choice_9_8_2,
#    3: Choice_9_8_3,
#    4: Choice_9_8_4,
#    5: Choice_9_8_5,
#    6: Choice_9_8_6,
#    7: Choice_9_8_7,
#    8: Choice_9_8_8,
#    9: Choice_9_8_9},
#   9: {1: Choice_9_9_1,
#    2: Choice_9_9_2,
#    3: Choice_9_9_3,
#    4: Choice_9_9_4,
#    5: Choice_9_9_5,
#    6: Choice_9_9_6,
#    7: Choice_9_9_7,
#    8: Choice_9_9_8,
#    9: Choice_9_9_9}}}

# %%
#  we don’t define an objective function since we are only concerned with any variable combination that can satisfy the constraints.
# any solution is good no better solution
# A constraint ensuring that only one value can be in each square is created
for r in ROWS:
    for c in COLS:
        prob += lpSum([choices[v][r][c] for v in VALS]) == 1

# %%
#These constraints ensure that each number (value) can only occur once in each row, column and box.
# The row, column and box constraints are added for each value
for v in VALS:
    for r in ROWS:
        prob += lpSum([choices[v][r][c] for c in COLS]) == 1

    for c in COLS:
        prob += lpSum([choices[v][r][c] for r in ROWS]) == 1

    for b in Boxes:
        prob += lpSum([choices[v][r][c] for (r, c) in b]) == 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# The starting numbers are entered as constraints i.e a 5 in row 1 column 1 is true.
# Starting State
input_data = [
    (5, 1, 1), # put 5 in row 1 col 1
    (6, 2, 1), # put 6 in row 2 col 1
    (8, 4, 1),
    (4, 5, 1),
    (7, 6, 1),
    (3, 1, 2),
    (9, 3, 2),
    (6, 7, 2),
    (8, 3, 3),
    (1, 2, 4),
    (8, 5, 4),
    (4, 8, 4),
    (7, 1, 5),
    (9, 2, 5),
    (6, 4, 5),
    (2, 6, 5),
    (1, 8, 5),
    (8, 9, 5),
    (5, 2, 6),
    (3, 5, 6),
    (9, 8, 6),
    (2, 7, 7),
    (6, 3, 8),
    (8, 7, 8),
    (7, 9, 8),
    (3, 4, 9),
    (1, 5, 9),
    (6, 6, 9),
    (5, 8, 9),
]

for v, r, c in input_data:
    prob += choices[v][r][c] == 1

# %%
prob
# Out:
# Sudoku_Problem:
# MINIMIZE
# None
# SUBJECT TO
# _C1: Choice_1_1_1 + Choice_2_1_1 + Choice_3_1_1 + Choice_4_1_1 + Choice_5_1_1
#  + Choice_6_1_1 + Choice_7_1_1 + Choice_8_1_1 + Choice_9_1_1 = 1
#
# _C2: Choice_1_1_2 + Choice_2_1_2 + Choice_3_1_2 + Choice_4_1_2 + Choice_5_1_2
#  + Choice_6_1_2 + Choice_7_1_2 + Choice_8_1_2 + Choice_9_1_2 = 1
#
# _C3: Choice_1_1_3 + Choice_2_1_3 + Choice_3_1_3 + Choice_4_1_3 + Choice_5_1_3
#  + Choice_6_1_3 + Choice_7_1_3 + Choice_8_1_3 + Choice_9_1_3 = 1
#
# _C4: Choice_1_1_4 + Choice_2_1_4 + Choice_3_1_4 + Choice_4_1_4 + Choice_5_1_4
#  + Choice_6_1_4 + Choice_7_1_4 + Choice_8_1_4 + Choice_9_1_4 = 1
#
# _C5: Choice_1_1_5 + Choice_2_1_5 + Choice_3_1_5 + Choice_4_1_5 + Choice_5_1_5
#  + Choice_6_1_5 + Choice_7_1_5 + Choice_8_1_5 + Choice_9_1_5 = 1
#
# _C6: Choice_1_1_6 + Choice_2_1_6 + Choice_3_1_6 + Choice_4_1_6 + Choice_5_1_6
#  + Choice_6_1_6 + Choice_7_1_6 + Choice_8_1_6 + Choice_9_1_6 = 1
#
# _C7: Choice_1_1_7 + Choice_2_1_7 + Choice_3_1_7 + Choice_4_1_7 + Choice_5_1_7
#  + Choice_6_1_7 + Choice_7_1_7 + Choice_8_1_7 + Choice_9_1_7 = 1
#
# _C8: Choice_1_1_8 + Choice_2_1_8 + Choice_3_1_8 + Choice_4_1_8 + Choice_5_1_8
#  + Choice_6_1_8 + Choice_7_1_8 + Choice_8_1_8 + Choice_9_1_8 = 1
#
# _C9: Choice_1_1_9 + Choice_2_1_9 + Choice_3_1_9 + Choice_4_1_9 + Choice_5_1_9
#  + Choice_6_1_9 + Choice_7_1_9 + Choice_8_1_9 + Choice_9_1_9 = 1
#
# _C10: Choice_1_2_1 + Choice_2_2_1 + Choice_3_2_1 + Choice_4_2_1 + Choice_5_2_1
#  + Choice_6_2_1 + Choice_7_2_1 + Choice_8_2_1 + Choice_9_2_1 = 1
#
# _C11: Choice_1_2_2 + Choice_2_2_2 + Choice_3_2_2 + Choice_4_2_2 + Choice_5_2_2
#  + Choice_6_2_2 + Choice_7_2_2 + Choice_8_2_2 + Choice_9_2_2 = 1
#
# _C12: Choice_1_2_3 + Choice_2_2_3 + Choice_3_2_3 + Choice_4_2_3 + Choice_5_2_3
#  + Choice_6_2_3 + Choice_7_2_3 + Choice_8_2_3 + Choice_9_2_3 = 1
#
# _C13: Choice_1_2_4 + Choice_2_2_4 + Choice_3_2_4 + Choice_4_2_4 + Choice_5_2_4
#  + Choice_6_2_4 + Choice_7_2_4 + Choice_8_2_4 + Choice_9_2_4 = 1
#
# _C14: Choice_1_2_5 + Choice_2_2_5 + Choice_3_2_5 + Choice_4_2_5 + Choice_5_2_5
#  + Choice_6_2_5 + Choice_7_2_5 + Choice_8_2_5 + Choice_9_2_5 = 1
#
# _C15: Choice_1_2_6 + Choice_2_2_6 + Choice_3_2_6 + Choice_4_2_6 + Choice_5_2_6
#  + Choice_6_2_6 + Choice_7_2_6 + Choice_8_2_6 + Choice_9_2_6 = 1
#
# _C16: Choice_1_2_7 + Choice_2_2_7 + Choice_3_2_7 + Choice_4_2_7 + Choice_5_2_7
#  + Choice_6_2_7 + Choice_7_2_7 + Choice_8_2_7 + Choice_9_2_7 = 1
#
# _C17: Choice_1_2_8 + Choice_2_2_8 + Choice_3_2_8 + Choice_4_2_8 + Choice_5_2_8
#  + Choice_6_2_8 + Choice_7_2_8 + Choice_8_2_8 + Choice_9_2_8 = 1
#
# _C18: Choice_1_2_9 + Choice_2_2_9 + Choice_3_2_9 + Choice_4_2_9 + Choice_5_2_9
#  + Choice_6_2_9 + Choice_7_2_9 + Choice_8_2_9 + Choice_9_2_9 = 1
#
# _C19: Choice_1_3_1 + Choice_2_3_1 + Choice_3_3_1 + Choice_4_3_1 + Choice_5_3_1
#  + Choice_6_3_1 + Choice_7_3_1 + Choice_8_3_1 + Choice_9_3_1 = 1
#
# _C20: Choice_1_3_2 + Choice_2_3_2 + Choice_3_3_2 + Choice_4_3_2 + Choice_5_3_2
#  + Choice_6_3_2 + Choice_7_3_2 + Choice_8_3_2 + Choice_9_3_2 = 1
#
# _C21: Choice_1_3_3 + Choice_2_3_3 + Choice_3_3_3 + Choice_4_3_3 + Choice_5_3_3
#  + Choice_6_3_3 + Choice_7_3_3 + Choice_8_3_3 + Choice_9_3_3 = 1
#
# _C22: Choice_1_3_4 + Choice_2_3_4 + Choice_3_3_4 + Choice_4_3_4 + Choice_5_3_4
#  + Choice_6_3_4 + Choice_7_3_4 + Choice_8_3_4 + Choice_9_3_4 = 1
#
# _C23: Choice_1_3_5 + Choice_2_3_5 + Choice_3_3_5 + Choice_4_3_5 + Choice_5_3_5
#  + Choice_6_3_5 + Choice_7_3_5 + Choice_8_3_5 + Choice_9_3_5 = 1
#
# _C24: Choice_1_3_6 + Choice_2_3_6 + Choice_3_3_6 + Choice_4_3_6 + Choice_5_3_6
#  + Choice_6_3_6 + Choice_7_3_6 + Choice_8_3_6 + Choice_9_3_6 = 1
#
# _C25: Choice_1_3_7 + Choice_2_3_7 + Choice_3_3_7 + Choice_4_3_7 + Choice_5_3_7
#  + Choice_6_3_7 + Choice_7_3_7 + Choice_8_3_7 + Choice_9_3_7 = 1
#
# _C26: Choice_1_3_8 + Choice_2_3_8 + Choice_3_3_8 + Choice_4_3_8 + Choice_5_3_8
#  + Choice_6_3_8 + Choice_7_3_8 + Choice_8_3_8 + Choice_9_3_8 = 1
#
# _C27: Choice_1_3_9 + Choice_2_3_9 + Choice_3_3_9 + Choice_4_3_9 + Choice_5_3_9
#  + Choice_6_3_9 + Choice_7_3_9 + Choice_8_3_9 + Choice_9_3_9 = 1
#
# _C28: Choice_1_4_1 + Choice_2_4_1 + Choice_3_4_1 + Choice_4_4_1 + Choice_5_4_1
#  + Choice_6_4_1 + Choice_7_4_1 + Choice_8_4_1 + Choice_9_4_1 = 1
#
# _C29: Choice_1_4_2 + Choice_2_4_2 + Choice_3_4_2 + Choice_4_4_2 + Choice_5_4_2
#  + Choice_6_4_2 + Choice_7_4_2 + Choice_8_4_2 + Choice_9_4_2 = 1
#
# _C30: Choice_1_4_3 + Choice_2_4_3 + Choice_3_4_3 + Choice_4_4_3 + Choice_5_4_3
#  + Choice_6_4_3 + Choice_7_4_3 + Choice_8_4_3 + Choice_9_4_3 = 1
#
# _C31: Choice_1_4_4 + Choice_2_4_4 + Choice_3_4_4 + Choice_4_4_4 + Choice_5_4_4
#  + Choice_6_4_4 + Choice_7_4_4 + Choice_8_4_4 + Choice_9_4_4 = 1
#
# _C32: Choice_1_4_5 + Choice_2_4_5 + Choice_3_4_5 + Choice_4_4_5 + Choice_5_4_5
#  + Choice_6_4_5 + Choice_7_4_5 + Choice_8_4_5 + Choice_9_4_5 = 1
#
# _C33: Choice_1_4_6 + Choice_2_4_6 + Choice_3_4_6 + Choice_4_4_6 + Choice_5_4_6
#  + Choice_6_4_6 + Choice_7_4_6 + Choice_8_4_6 + Choice_9_4_6 = 1
#
# _C34: Choice_1_4_7 + Choice_2_4_7 + Choice_3_4_7 + Choice_4_4_7 + Choice_5_4_7
#  + Choice_6_4_7 + Choice_7_4_7 + Choice_8_4_7 + Choice_9_4_7 = 1
#
# _C35: Choice_1_4_8 + Choice_2_4_8 + Choice_3_4_8 + Choice_4_4_8 + Choice_5_4_8
#  + Choice_6_4_8 + Choice_7_4_8 + Choice_8_4_8 + Choice_9_4_8 = 1
#
# _C36: Choice_1_4_9 + Choice_2_4_9 + Choice_3_4_9 + Choice_4_4_9 + Choice_5_4_9
#  + Choice_6_4_9 + Choice_7_4_9 + Choice_8_4_9 + Choice_9_4_9 = 1
#
# _C37: Choice_1_5_1 + Choice_2_5_1 + Choice_3_5_1 + Choice_4_5_1 + Choice_5_5_1
#  + Choice_6_5_1 + Choice_7_5_1 + Choice_8_5_1 + Choice_9_5_1 = 1
#
# _C38: Choice_1_5_2 + Choice_2_5_2 + Choice_3_5_2 + Choice_4_5_2 + Choice_5_5_2
#  + Choice_6_5_2 + Choice_7_5_2 + Choice_8_5_2 + Choice_9_5_2 = 1
#
# _C39: Choice_1_5_3 + Choice_2_5_3 + Choice_3_5_3 + Choice_4_5_3 + Choice_5_5_3
#  + Choice_6_5_3 + Choice_7_5_3 + Choice_8_5_3 + Choice_9_5_3 = 1
#
# _C40: Choice_1_5_4 + Choice_2_5_4 + Choice_3_5_4 + Choice_4_5_4 + Choice_5_5_4
#  + Choice_6_5_4 + Choice_7_5_4 + Choice_8_5_4 + Choice_9_5_4 = 1
#
# _C41: Choice_1_5_5 + Choice_2_5_5 + Choice_3_5_5 + Choice_4_5_5 + Choice_5_5_5
#  + Choice_6_5_5 + Choice_7_5_5 + Choice_8_5_5 + Choice_9_5_5 = 1
#
# _C42: Choice_1_5_6 + Choice_2_5_6 + Choice_3_5_6 + Choice_4_5_6 + Choice_5_5_6
#  + Choice_6_5_6 + Choice_7_5_6 + Choice_8_5_6 + Choice_9_5_6 = 1
#
# _C43: Choice_1_5_7 + Choice_2_5_7 + Choice_3_5_7 + Choice_4_5_7 + Choice_5_5_7
#  + Choice_6_5_7 + Choice_7_5_7 + Choice_8_5_7 + Choice_9_5_7 = 1
#
# _C44: Choice_1_5_8 + Choice_2_5_8 + Choice_3_5_8 + Choice_4_5_8 + Choice_5_5_8
#  + Choice_6_5_8 + Choice_7_5_8 + Choice_8_5_8 + Choice_9_5_8 = 1
#
# _C45: Choice_1_5_9 + Choice_2_5_9 + Choice_3_5_9 + Choice_4_5_9 + Choice_5_5_9
#  + Choice_6_5_9 + Choice_7_5_9 + Choice_8_5_9 + Choice_9_5_9 = 1
#
# _C46: Choice_1_6_1 + Choice_2_6_1 + Choice_3_6_1 + Choice_4_6_1 + Choice_5_6_1
#  + Choice_6_6_1 + Choice_7_6_1 + Choice_8_6_1 + Choice_9_6_1 = 1
#
# _C47: Choice_1_6_2 + Choice_2_6_2 + Choice_3_6_2 + Choice_4_6_2 + Choice_5_6_2
#  + Choice_6_6_2 + Choice_7_6_2 + Choice_8_6_2 + Choice_9_6_2 = 1
#
# _C48: Choice_1_6_3 + Choice_2_6_3 + Choice_3_6_3 + Choice_4_6_3 + Choice_5_6_3
#  + Choice_6_6_3 + Choice_7_6_3 + Choice_8_6_3 + Choice_9_6_3 = 1
#
# _C49: Choice_1_6_4 + Choice_2_6_4 + Choice_3_6_4 + Choice_4_6_4 + Choice_5_6_4
#  + Choice_6_6_4 + Choice_7_6_4 + Choice_8_6_4 + Choice_9_6_4 = 1
#
# _C50: Choice_1_6_5 + Choice_2_6_5 + Choice_3_6_5 + Choice_4_6_5 + Choice_5_6_5
#  + Choice_6_6_5 + Choice_7_6_5 + Choice_8_6_5 + Choice_9_6_5 = 1
#
# _C51: Choice_1_6_6 + Choice_2_6_6 + Choice_3_6_6 + Choice_4_6_6 + Choice_5_6_6
#  + Choice_6_6_6 + Choice_7_6_6 + Choice_8_6_6 + Choice_9_6_6 = 1
#
# _C52: Choice_1_6_7 + Choice_2_6_7 + Choice_3_6_7 + Choice_4_6_7 + Choice_5_6_7
#  + Choice_6_6_7 + Choice_7_6_7 + Choice_8_6_7 + Choice_9_6_7 = 1
#
# _C53: Choice_1_6_8 + Choice_2_6_8 + Choice_3_6_8 + Choice_4_6_8 + Choice_5_6_8
#  + Choice_6_6_8 + Choice_7_6_8 + Choice_8_6_8 + Choice_9_6_8 = 1
#
# _C54: Choice_1_6_9 + Choice_2_6_9 + Choice_3_6_9 + Choice_4_6_9 + Choice_5_6_9
#  + Choice_6_6_9 + Choice_7_6_9 + Choice_8_6_9 + Choice_9_6_9 = 1
#
# _C55: Choice_1_7_1 + Choice_2_7_1 + Choice_3_7_1 + Choice_4_7_1 + Choice_5_7_1
#  + Choice_6_7_1 + Choice_7_7_1 + Choice_8_7_1 + Choice_9_7_1 = 1
#
# _C56: Choice_1_7_2 + Choice_2_7_2 + Choice_3_7_2 + Choice_4_7_2 + Choice_5_7_2
#  + Choice_6_7_2 + Choice_7_7_2 + Choice_8_7_2 + Choice_9_7_2 = 1
#
# _C57: Choice_1_7_3 + Choice_2_7_3 + Choice_3_7_3 + Choice_4_7_3 + Choice_5_7_3
#  + Choice_6_7_3 + Choice_7_7_3 + Choice_8_7_3 + Choice_9_7_3 = 1
#
# _C58: Choice_1_7_4 + Choice_2_7_4 + Choice_3_7_4 + Choice_4_7_4 + Choice_5_7_4
#  + Choice_6_7_4 + Choice_7_7_4 + Choice_8_7_4 + Choice_9_7_4 = 1
#
# _C59: Choice_1_7_5 + Choice_2_7_5 + Choice_3_7_5 + Choice_4_7_5 + Choice_5_7_5
#  + Choice_6_7_5 + Choice_7_7_5 + Choice_8_7_5 + Choice_9_7_5 = 1
#
# _C60: Choice_1_7_6 + Choice_2_7_6 + Choice_3_7_6 + Choice_4_7_6 + Choice_5_7_6
#  + Choice_6_7_6 + Choice_7_7_6 + Choice_8_7_6 + Choice_9_7_6 = 1
#
# _C61: Choice_1_7_7 + Choice_2_7_7 + Choice_3_7_7 + Choice_4_7_7 + Choice_5_7_7
#  + Choice_6_7_7 + Choice_7_7_7 + Choice_8_7_7 + Choice_9_7_7 = 1
#
# _C62: Choice_1_7_8 + Choice_2_7_8 + Choice_3_7_8 + Choice_4_7_8 + Choice_5_7_8
#  + Choice_6_7_8 + Choice_7_7_8 + Choice_8_7_8 + Choice_9_7_8 = 1
#
# _C63: Choice_1_7_9 + Choice_2_7_9 + Choice_3_7_9 + Choice_4_7_9 + Choice_5_7_9
#  + Choice_6_7_9 + Choice_7_7_9 + Choice_8_7_9 + Choice_9_7_9 = 1
#
# _C64: Choice_1_8_1 + Choice_2_8_1 + Choice_3_8_1 + Choice_4_8_1 + Choice_5_8_1
#  + Choice_6_8_1 + Choice_7_8_1 + Choice_8_8_1 + Choice_9_8_1 = 1
#
# _C65: Choice_1_8_2 + Choice_2_8_2 + Choice_3_8_2 + Choice_4_8_2 + Choice_5_8_2
#  + Choice_6_8_2 + Choice_7_8_2 + Choice_8_8_2 + Choice_9_8_2 = 1
#
# _C66: Choice_1_8_3 + Choice_2_8_3 + Choice_3_8_3 + Choice_4_8_3 + Choice_5_8_3
#  + Choice_6_8_3 + Choice_7_8_3 + Choice_8_8_3 + Choice_9_8_3 = 1
#
# _C67: Choice_1_8_4 + Choice_2_8_4 + Choice_3_8_4 + Choice_4_8_4 + Choice_5_8_4
#  + Choice_6_8_4 + Choice_7_8_4 + Choice_8_8_4 + Choice_9_8_4 = 1
#
# _C68: Choice_1_8_5 + Choice_2_8_5 + Choice_3_8_5 + Choice_4_8_5 + Choice_5_8_5
#  + Choice_6_8_5 + Choice_7_8_5 + Choice_8_8_5 + Choice_9_8_5 = 1
#
# _C69: Choice_1_8_6 + Choice_2_8_6 + Choice_3_8_6 + Choice_4_8_6 + Choice_5_8_6
#  + Choice_6_8_6 + Choice_7_8_6 + Choice_8_8_6 + Choice_9_8_6 = 1
#
# _C70: Choice_1_8_7 + Choice_2_8_7 + Choice_3_8_7 + Choice_4_8_7 + Choice_5_8_7
#  + Choice_6_8_7 + Choice_7_8_7 + Choice_8_8_7 + Choice_9_8_7 = 1
#
# _C71: Choice_1_8_8 + Choice_2_8_8 + Choice_3_8_8 + Choice_4_8_8 + Choice_5_8_8
#  + Choice_6_8_8 + Choice_7_8_8 + Choice_8_8_8 + Choice_9_8_8 = 1
#
# _C72: Choice_1_8_9 + Choice_2_8_9 + Choice_3_8_9 + Choice_4_8_9 + Choice_5_8_9
#  + Choice_6_8_9 + Choice_7_8_9 + Choice_8_8_9 + Choice_9_8_9 = 1
#
# _C73: Choice_1_9_1 + Choice_2_9_1 + Choice_3_9_1 + Choice_4_9_1 + Choice_5_9_1
#  + Choice_6_9_1 + Choice_7_9_1 + Choice_8_9_1 + Choice_9_9_1 = 1
#
# _C74: Choice_1_9_2 + Choice_2_9_2 + Choice_3_9_2 + Choice_4_9_2 + Choice_5_9_2
#  + Choice_6_9_2 + Choice_7_9_2 + Choice_8_9_2 + Choice_9_9_2 = 1
#
# _C75: Choice_1_9_3 + Choice_2_9_3 + Choice_3_9_3 + Choice_4_9_3 + Choice_5_9_3
#  + Choice_6_9_3 + Choice_7_9_3 + Choice_8_9_3 + Choice_9_9_3 = 1
#
# _C76: Choice_1_9_4 + Choice_2_9_4 + Choice_3_9_4 + Choice_4_9_4 + Choice_5_9_4
#  + Choice_6_9_4 + Choice_7_9_4 + Choice_8_9_4 + Choice_9_9_4 = 1
#
# _C77: Choice_1_9_5 + Choice_2_9_5 + Choice_3_9_5 + Choice_4_9_5 + Choice_5_9_5
#  + Choice_6_9_5 + Choice_7_9_5 + Choice_8_9_5 + Choice_9_9_5 = 1
#
# _C78: Choice_1_9_6 + Choice_2_9_6 + Choice_3_9_6 + Choice_4_9_6 + Choice_5_9_6
#  + Choice_6_9_6 + Choice_7_9_6 + Choice_8_9_6 + Choice_9_9_6 = 1
#
# _C79: Choice_1_9_7 + Choice_2_9_7 + Choice_3_9_7 + Choice_4_9_7 + Choice_5_9_7
#  + Choice_6_9_7 + Choice_7_9_7 + Choice_8_9_7 + Choice_9_9_7 = 1
#
# _C80: Choice_1_9_8 + Choice_2_9_8 + Choice_3_9_8 + Choice_4_9_8 + Choice_5_9_8
#  + Choice_6_9_8 + Choice_7_9_8 + Choice_8_9_8 + Choice_9_9_8 = 1
#
# _C81: Choice_1_9_9 + Choice_2_9_9 + Choice_3_9_9 + Choice_4_9_9 + Choice_5_9_9
#  + Choice_6_9_9 + Choice_7_9_9 + Choice_8_9_9 + Choice_9_9_9 = 1
#
# _C82: Choice_1_1_1 + Choice_1_1_2 + Choice_1_1_3 + Choice_1_1_4 + Choice_1_1_5
#  + Choice_1_1_6 + Choice_1_1_7 + Choice_1_1_8 + Choice_1_1_9 = 1
#
# _C83: Choice_1_2_1 + Choice_1_2_2 + Choice_1_2_3 + Choice_1_2_4 + Choice_1_2_5
#  + Choice_1_2_6 + Choice_1_2_7 + Choice_1_2_8 + Choice_1_2_9 = 1
#
# _C84: Choice_1_3_1 + Choice_1_3_2 + Choice_1_3_3 + Choice_1_3_4 + Choice_1_3_5
#  + Choice_1_3_6 + Choice_1_3_7 + Choice_1_3_8 + Choice_1_3_9 = 1
#
# _C85: Choice_1_4_1 + Choice_1_4_2 + Choice_1_4_3 + Choice_1_4_4 + Choice_1_4_5
#  + Choice_1_4_6 + Choice_1_4_7 + Choice_1_4_8 + Choice_1_4_9 = 1
#
# _C86: Choice_1_5_1 + Choice_1_5_2 + Choice_1_5_3 + Choice_1_5_4 + Choice_1_5_5
#  + Choice_1_5_6 + Choice_1_5_7 + Choice_1_5_8 + Choice_1_5_9 = 1
#
# _C87: Choice_1_6_1 + Choice_1_6_2 + Choice_1_6_3 + Choice_1_6_4 + Choice_1_6_5
#  + Choice_1_6_6 + Choice_1_6_7 + Choice_1_6_8 + Choice_1_6_9 = 1
#
# _C88: Choice_1_7_1 + Choice_1_7_2 + Choice_1_7_3 + Choice_1_7_4 + Choice_1_7_5
#  + Choice_1_7_6 + Choice_1_7_7 + Choice_1_7_8 + Choice_1_7_9 = 1
#
# _C89: Choice_1_8_1 + Choice_1_8_2 + Choice_1_8_3 + Choice_1_8_4 + Choice_1_8_5
#  + Choice_1_8_6 + Choice_1_8_7 + Choice_1_8_8 + Choice_1_8_9 = 1
#
# _C90: Choice_1_9_1 + Choice_1_9_2 + Choice_1_9_3 + Choice_1_9_4 + Choice_1_9_5
#  + Choice_1_9_6 + Choice_1_9_7 + Choice_1_9_8 + Choice_1_9_9 = 1
#
# _C91: Choice_1_1_1 + Choice_1_2_1 + Choice_1_3_1 + Choice_1_4_1 + Choice_1_5_1
#  + Choice_1_6_1 + Choice_1_7_1 + Choice_1_8_1 + Choice_1_9_1 = 1
#
# _C92: Choice_1_1_2 + Choice_1_2_2 + Choice_1_3_2 + Choice_1_4_2 + Choice_1_5_2
#  + Choice_1_6_2 + Choice_1_7_2 + Choice_1_8_2 + Choice_1_9_2 = 1
#
# _C93: Choice_1_1_3 + Choice_1_2_3 + Choice_1_3_3 + Choice_1_4_3 + Choice_1_5_3
#  + Choice_1_6_3 + Choice_1_7_3 + Choice_1_8_3 + Choice_1_9_3 = 1
#
# _C94: Choice_1_1_4 + Choice_1_2_4 + Choice_1_3_4 + Choice_1_4_4 + Choice_1_5_4
#  + Choice_1_6_4 + Choice_1_7_4 + Choice_1_8_4 + Choice_1_9_4 = 1
#
# _C95: Choice_1_1_5 + Choice_1_2_5 + Choice_1_3_5 + Choice_1_4_5 + Choice_1_5_5
#  + Choice_1_6_5 + Choice_1_7_5 + Choice_1_8_5 + Choice_1_9_5 = 1
#
# _C96: Choice_1_1_6 + Choice_1_2_6 + Choice_1_3_6 + Choice_1_4_6 + Choice_1_5_6
#  + Choice_1_6_6 + Choice_1_7_6 + Choice_1_8_6 + Choice_1_9_6 = 1
#
# _C97: Choice_1_1_7 + Choice_1_2_7 + Choice_1_3_7 + Choice_1_4_7 + Choice_1_5_7
#  + Choice_1_6_7 + Choice_1_7_7 + Choice_1_8_7 + Choice_1_9_7 = 1
#
# _C98: Choice_1_1_8 + Choice_1_2_8 + Choice_1_3_8 + Choice_1_4_8 + Choice_1_5_8
#  + Choice_1_6_8 + Choice_1_7_8 + Choice_1_8_8 + Choice_1_9_8 = 1
#
# _C99: Choice_1_1_9 + Choice_1_2_9 + Choice_1_3_9 + Choice_1_4_9 + Choice_1_5_9
#  + Choice_1_6_9 + Choice_1_7_9 + Choice_1_8_9 + Choice_1_9_9 = 1
#
# _C100: Choice_1_1_1 + Choice_1_1_2 + Choice_1_1_3 + Choice_1_2_1
#  + Choice_1_2_2 + Choice_1_2_3 + Choice_1_3_1 + Choice_1_3_2 + Choice_1_3_3
#  = 1
#
# _C101: Choice_1_1_4 + Choice_1_1_5 + Choice_1_1_6 + Choice_1_2_4
#  + Choice_1_2_5 + Choice_1_2_6 + Choice_1_3_4 + Choice_1_3_5 + Choice_1_3_6
#  = 1
#
# _C102: Choice_1_1_7 + Choice_1_1_8 + Choice_1_1_9 + Choice_1_2_7
#  + Choice_1_2_8 + Choice_1_2_9 + Choice_1_3_7 + Choice_1_3_8 + Choice_1_3_9
#  = 1
#
# _C103: Choice_1_4_1 + Choice_1_4_2 + Choice_1_4_3 + Choice_1_5_1
#  + Choice_1_5_2 + Choice_1_5_3 + Choice_1_6_1 + Choice_1_6_2 + Choice_1_6_3
#  = 1
#
# _C104: Choice_1_4_4 + Choice_1_4_5 + Choice_1_4_6 + Choice_1_5_4
#  + Choice_1_5_5 + Choice_1_5_6 + Choice_1_6_4 + Choice_1_6_5 + Choice_1_6_6
#  = 1
#
# _C105: Choice_1_4_7 + Choice_1_4_8 + Choice_1_4_9 + Choice_1_5_7
#  + Choice_1_5_8 + Choice_1_5_9 + Choice_1_6_7 + Choice_1_6_8 + Choice_1_6_9
#  = 1
#
# _C106: Choice_1_7_1 + Choice_1_7_2 + Choice_1_7_3 + Choice_1_8_1
#  + Choice_1_8_2 + Choice_1_8_3 + Choice_1_9_1 + Choice_1_9_2 + Choice_1_9_3
#  = 1
#
# _C107: Choice_1_7_4 + Choice_1_7_5 + Choice_1_7_6 + Choice_1_8_4
#  + Choice_1_8_5 + Choice_1_8_6 + Choice_1_9_4 + Choice_1_9_5 + Choice_1_9_6
#  = 1
#
# _C108: Choice_1_7_7 + Choice_1_7_8 + Choice_1_7_9 + Choice_1_8_7
#  + Choice_1_8_8 + Choice_1_8_9 + Choice_1_9_7 + Choice_1_9_8 + Choice_1_9_9
#  = 1
#
# _C109: Choice_2_1_1 + Choice_2_1_2 + Choice_2_1_3 + Choice_2_1_4
#  + Choice_2_1_5 + Choice_2_1_6 + Choice_2_1_7 + Choice_2_1_8 + Choice_2_1_9
#  = 1
#
# _C110: Choice_2_2_1 + Choice_2_2_2 + Choice_2_2_3 + Choice_2_2_4
#  + Choice_2_2_5 + Choice_2_2_6 + Choice_2_2_7 + Choice_2_2_8 + Choice_2_2_9
#  = 1
#
# _C111: Choice_2_3_1 + Choice_2_3_2 + Choice_2_3_3 + Choice_2_3_4
#  + Choice_2_3_5 + Choice_2_3_6 + Choice_2_3_7 + Choice_2_3_8 + Choice_2_3_9
#  = 1
#
# _C112: Choice_2_4_1 + Choice_2_4_2 + Choice_2_4_3 + Choice_2_4_4
#  + Choice_2_4_5 + Choice_2_4_6 + Choice_2_4_7 + Choice_2_4_8 + Choice_2_4_9
#  = 1
#
# _C113: Choice_2_5_1 + Choice_2_5_2 + Choice_2_5_3 + Choice_2_5_4
#  + Choice_2_5_5 + Choice_2_5_6 + Choice_2_5_7 + Choice_2_5_8 + Choice_2_5_9
#  = 1
#
# _C114: Choice_2_6_1 + Choice_2_6_2 + Choice_2_6_3 + Choice_2_6_4
#  + Choice_2_6_5 + Choice_2_6_6 + Choice_2_6_7 + Choice_2_6_8 + Choice_2_6_9
#  = 1
#
# _C115: Choice_2_7_1 + Choice_2_7_2 + Choice_2_7_3 + Choice_2_7_4
#  + Choice_2_7_5 + Choice_2_7_6 + Choice_2_7_7 + Choice_2_7_8 + Choice_2_7_9
#  = 1
#
# _C116: Choice_2_8_1 + Choice_2_8_2 + Choice_2_8_3 + Choice_2_8_4
#  + Choice_2_8_5 + Choice_2_8_6 + Choice_2_8_7 + Choice_2_8_8 + Choice_2_8_9
#  = 1
#
# _C117: Choice_2_9_1 + Choice_2_9_2 + Choice_2_9_3 + Choice_2_9_4
#  + Choice_2_9_5 + Choice_2_9_6 + Choice_2_9_7 + Choice_2_9_8 + Choice_2_9_9
#  = 1
#
# _C118: Choice_2_1_1 + Choice_2_2_1 + Choice_2_3_1 + Choice_2_4_1
#  + Choice_2_5_1 + Choice_2_6_1 + Choice_2_7_1 + Choice_2_8_1 + Choice_2_9_1
#  = 1
#
# _C119: Choice_2_1_2 + Choice_2_2_2 + Choice_2_3_2 + Choice_2_4_2
#  + Choice_2_5_2 + Choice_2_6_2 + Choice_2_7_2 + Choice_2_8_2 + Choice_2_9_2
#  = 1
#
# _C120: Choice_2_1_3 + Choice_2_2_3 + Choice_2_3_3 + Choice_2_4_3
#  + Choice_2_5_3 + Choice_2_6_3 + Choice_2_7_3 + Choice_2_8_3 + Choice_2_9_3
#  = 1
#
# _C121: Choice_2_1_4 + Choice_2_2_4 + Choice_2_3_4 + Choice_2_4_4
#  + Choice_2_5_4 + Choice_2_6_4 + Choice_2_7_4 + Choice_2_8_4 + Choice_2_9_4
#  = 1
#
# _C122: Choice_2_1_5 + Choice_2_2_5 + Choice_2_3_5 + Choice_2_4_5
#  + Choice_2_5_5 + Choice_2_6_5 + Choice_2_7_5 + Choice_2_8_5 + Choice_2_9_5
#  = 1
#
# _C123: Choice_2_1_6 + Choice_2_2_6 + Choice_2_3_6 + Choice_2_4_6
#  + Choice_2_5_6 + Choice_2_6_6 + Choice_2_7_6 + Choice_2_8_6 + Choice_2_9_6
#  = 1
#
# _C124: Choice_2_1_7 + Choice_2_2_7 + Choice_2_3_7 + Choice_2_4_7
#  + Choice_2_5_7 + Choice_2_6_7 + Choice_2_7_7 + Choice_2_8_7 + Choice_2_9_7
#  = 1
#
# _C125: Choice_2_1_8 + Choice_2_2_8 + Choice_2_3_8 + Choice_2_4_8
#  + Choice_2_5_8 + Choice_2_6_8 + Choice_2_7_8 + Choice_2_8_8 + Choice_2_9_8
#  = 1
#
# _C126: Choice_2_1_9 + Choice_2_2_9 + Choice_2_3_9 + Choice_2_4_9
#  + Choice_2_5_9 + Choice_2_6_9 + Choice_2_7_9 + Choice_2_8_9 + Choice_2_9_9
#  = 1
#
# _C127: Choice_2_1_1 + Choice_2_1_2 + Choice_2_1_3 + Choice_2_2_1
#  + Choice_2_2_2 + Choice_2_2_3 + Choice_2_3_1 + Choice_2_3_2 + Choice_2_3_3
#  = 1
#
# _C128: Choice_2_1_4 + Choice_2_1_5 + Choice_2_1_6 + Choice_2_2_4
#  + Choice_2_2_5 + Choice_2_2_6 + Choice_2_3_4 + Choice_2_3_5 + Choice_2_3_6
#  = 1
#
# _C129: Choice_2_1_7 + Choice_2_1_8 + Choice_2_1_9 + Choice_2_2_7
#  + Choice_2_2_8 + Choice_2_2_9 + Choice_2_3_7 + Choice_2_3_8 + Choice_2_3_9
#  = 1
#
# _C130: Choice_2_4_1 + Choice_2_4_2 + Choice_2_4_3 + Choice_2_5_1
#  + Choice_2_5_2 + Choice_2_5_3 + Choice_2_6_1 + Choice_2_6_2 + Choice_2_6_3
#  = 1
#
# _C131: Choice_2_4_4 + Choice_2_4_5 + Choice_2_4_6 + Choice_2_5_4
#  + Choice_2_5_5 + Choice_2_5_6 + Choice_2_6_4 + Choice_2_6_5 + Choice_2_6_6
#  = 1
#
# _C132: Choice_2_4_7 + Choice_2_4_8 + Choice_2_4_9 + Choice_2_5_7
#  + Choice_2_5_8 + Choice_2_5_9 + Choice_2_6_7 + Choice_2_6_8 + Choice_2_6_9
#  = 1
#
# _C133: Choice_2_7_1 + Choice_2_7_2 + Choice_2_7_3 + Choice_2_8_1
#  + Choice_2_8_2 + Choice_2_8_3 + Choice_2_9_1 + Choice_2_9_2 + Choice_2_9_3
#  = 1
#
# _C134: Choice_2_7_4 + Choice_2_7_5 + Choice_2_7_6 + Choice_2_8_4
#  + Choice_2_8_5 + Choice_2_8_6 + Choice_2_9_4 + Choice_2_9_5 + Choice_2_9_6
#  = 1
#
# _C135: Choice_2_7_7 + Choice_2_7_8 + Choice_2_7_9 + Choice_2_8_7
#  + Choice_2_8_8 + Choice_2_8_9 + Choice_2_9_7 + Choice_2_9_8 + Choice_2_9_9
#  = 1
#
# _C136: Choice_3_1_1 + Choice_3_1_2 + Choice_3_1_3 + Choice_3_1_4
#  + Choice_3_1_5 + Choice_3_1_6 + Choice_3_1_7 + Choice_3_1_8 + Choice_3_1_9
#  = 1
#
# _C137: Choice_3_2_1 + Choice_3_2_2 + Choice_3_2_3 + Choice_3_2_4
#  + Choice_3_2_5 + Choice_3_2_6 + Choice_3_2_7 + Choice_3_2_8 + Choice_3_2_9
#  = 1
#
# _C138: Choice_3_3_1 + Choice_3_3_2 + Choice_3_3_3 + Choice_3_3_4
#  + Choice_3_3_5 + Choice_3_3_6 + Choice_3_3_7 + Choice_3_3_8 + Choice_3_3_9
#  = 1
#
# _C139: Choice_3_4_1 + Choice_3_4_2 + Choice_3_4_3 + Choice_3_4_4
#  + Choice_3_4_5 + Choice_3_4_6 + Choice_3_4_7 + Choice_3_4_8 + Choice_3_4_9
#  = 1
#
# _C140: Choice_3_5_1 + Choice_3_5_2 + Choice_3_5_3 + Choice_3_5_4
#  + Choice_3_5_5 + Choice_3_5_6 + Choice_3_5_7 + Choice_3_5_8 + Choice_3_5_9
#  = 1
#
# _C141: Choice_3_6_1 + Choice_3_6_2 + Choice_3_6_3 + Choice_3_6_4
#  + Choice_3_6_5 + Choice_3_6_6 + Choice_3_6_7 + Choice_3_6_8 + Choice_3_6_9
#  = 1
#
# _C142: Choice_3_7_1 + Choice_3_7_2 + Choice_3_7_3 + Choice_3_7_4
#  + Choice_3_7_5 + Choice_3_7_6 + Choice_3_7_7 + Choice_3_7_8 + Choice_3_7_9
#  = 1
#
# _C143: Choice_3_8_1 + Choice_3_8_2 + Choice_3_8_3 + Choice_3_8_4
#  + Choice_3_8_5 + Choice_3_8_6 + Choice_3_8_7 + Choice_3_8_8 + Choice_3_8_9
#  = 1
#
# _C144: Choice_3_9_1 + Choice_3_9_2 + Choice_3_9_3 + Choice_3_9_4
#  + Choice_3_9_5 + Choice_3_9_6 + Choice_3_9_7 + Choice_3_9_8 + Choice_3_9_9
#  = 1
#
# _C145: Choice_3_1_1 + Choice_3_2_1 + Choice_3_3_1 + Choice_3_4_1
#  + Choice_3_5_1 + Choice_3_6_1 + Choice_3_7_1 + Choice_3_8_1 + Choice_3_9_1
#  = 1
#
# _C146: Choice_3_1_2 + Choice_3_2_2 + Choice_3_3_2 + Choice_3_4_2
#  + Choice_3_5_2 + Choice_3_6_2 + Choice_3_7_2 + Choice_3_8_2 + Choice_3_9_2
#  = 1
#
# _C147: Choice_3_1_3 + Choice_3_2_3 + Choice_3_3_3 + Choice_3_4_3
#  + Choice_3_5_3 + Choice_3_6_3 + Choice_3_7_3 + Choice_3_8_3 + Choice_3_9_3
#  = 1
#
# _C148: Choice_3_1_4 + Choice_3_2_4 + Choice_3_3_4 + Choice_3_4_4
#  + Choice_3_5_4 + Choice_3_6_4 + Choice_3_7_4 + Choice_3_8_4 + Choice_3_9_4
#  = 1
#
# _C149: Choice_3_1_5 + Choice_3_2_5 + Choice_3_3_5 + Choice_3_4_5
#  + Choice_3_5_5 + Choice_3_6_5 + Choice_3_7_5 + Choice_3_8_5 + Choice_3_9_5
#  = 1
#
# _C150: Choice_3_1_6 + Choice_3_2_6 + Choice_3_3_6 + Choice_3_4_6
#  + Choice_3_5_6 + Choice_3_6_6 + Choice_3_7_6 + Choice_3_8_6 + Choice_3_9_6
#  = 1
#
# _C151: Choice_3_1_7 + Choice_3_2_7 + Choice_3_3_7 + Choice_3_4_7
#  + Choice_3_5_7 + Choice_3_6_7 + Choice_3_7_7 + Choice_3_8_7 + Choice_3_9_7
#  = 1
#
# _C152: Choice_3_1_8 + Choice_3_2_8 + Choice_3_3_8 + Choice_3_4_8
#  + Choice_3_5_8 + Choice_3_6_8 + Choice_3_7_8 + Choice_3_8_8 + Choice_3_9_8
#  = 1
#
# _C153: Choice_3_1_9 + Choice_3_2_9 + Choice_3_3_9 + Choice_3_4_9
#  + Choice_3_5_9 + Choice_3_6_9 + Choice_3_7_9 + Choice_3_8_9 + Choice_3_9_9
#  = 1
#
# _C154: Choice_3_1_1 + Choice_3_1_2 + Choice_3_1_3 + Choice_3_2_1
#  + Choice_3_2_2 + Choice_3_2_3 + Choice_3_3_1 + Choice_3_3_2 + Choice_3_3_3
#  = 1
#
# _C155: Choice_3_1_4 + Choice_3_1_5 + Choice_3_1_6 + Choice_3_2_4
#  + Choice_3_2_5 + Choice_3_2_6 + Choice_3_3_4 + Choice_3_3_5 + Choice_3_3_6
#  = 1
#
# _C156: Choice_3_1_7 + Choice_3_1_8 + Choice_3_1_9 + Choice_3_2_7
#  + Choice_3_2_8 + Choice_3_2_9 + Choice_3_3_7 + Choice_3_3_8 + Choice_3_3_9
#  = 1
#
# _C157: Choice_3_4_1 + Choice_3_4_2 + Choice_3_4_3 + Choice_3_5_1
#  + Choice_3_5_2 + Choice_3_5_3 + Choice_3_6_1 + Choice_3_6_2 + Choice_3_6_3
#  = 1
#
# _C158: Choice_3_4_4 + Choice_3_4_5 + Choice_3_4_6 + Choice_3_5_4
#  + Choice_3_5_5 + Choice_3_5_6 + Choice_3_6_4 + Choice_3_6_5 + Choice_3_6_6
#  = 1
#
# _C159: Choice_3_4_7 + Choice_3_4_8 + Choice_3_4_9 + Choice_3_5_7
#  + Choice_3_5_8 + Choice_3_5_9 + Choice_3_6_7 + Choice_3_6_8 + Choice_3_6_9
#  = 1
#
# _C160: Choice_3_7_1 + Choice_3_7_2 + Choice_3_7_3 + Choice_3_8_1
#  + Choice_3_8_2 + Choice_3_8_3 + Choice_3_9_1 + Choice_3_9_2 + Choice_3_9_3
#  = 1
#
# _C161: Choice_3_7_4 + Choice_3_7_5 + Choice_3_7_6 + Choice_3_8_4
#  + Choice_3_8_5 + Choice_3_8_6 + Choice_3_9_4 + Choice_3_9_5 + Choice_3_9_6
#  = 1
#
# _C162: Choice_3_7_7 + Choice_3_7_8 + Choice_3_7_9 + Choice_3_8_7
#  + Choice_3_8_8 + Choice_3_8_9 + Choice_3_9_7 + Choice_3_9_8 + Choice_3_9_9
#  = 1
#
# _C163: Choice_4_1_1 + Choice_4_1_2 + Choice_4_1_3 + Choice_4_1_4
#  + Choice_4_1_5 + Choice_4_1_6 + Choice_4_1_7 + Choice_4_1_8 + Choice_4_1_9
#  = 1
#
# _C164: Choice_4_2_1 + Choice_4_2_2 + Choice_4_2_3 + Choice_4_2_4
#  + Choice_4_2_5 + Choice_4_2_6 + Choice_4_2_7 + Choice_4_2_8 + Choice_4_2_9
#  = 1
#
# _C165: Choice_4_3_1 + Choice_4_3_2 + Choice_4_3_3 + Choice_4_3_4
#  + Choice_4_3_5 + Choice_4_3_6 + Choice_4_3_7 + Choice_4_3_8 + Choice_4_3_9
#  = 1
#
# _C166: Choice_4_4_1 + Choice_4_4_2 + Choice_4_4_3 + Choice_4_4_4
#  + Choice_4_4_5 + Choice_4_4_6 + Choice_4_4_7 + Choice_4_4_8 + Choice_4_4_9
#  = 1
#
# _C167: Choice_4_5_1 + Choice_4_5_2 + Choice_4_5_3 + Choice_4_5_4
#  + Choice_4_5_5 + Choice_4_5_6 + Choice_4_5_7 + Choice_4_5_8 + Choice_4_5_9
#  = 1
#
# _C168: Choice_4_6_1 + Choice_4_6_2 + Choice_4_6_3 + Choice_4_6_4
#  + Choice_4_6_5 + Choice_4_6_6 + Choice_4_6_7 + Choice_4_6_8 + Choice_4_6_9
#  = 1
#
# _C169: Choice_4_7_1 + Choice_4_7_2 + Choice_4_7_3 + Choice_4_7_4
#  + Choice_4_7_5 + Choice_4_7_6 + Choice_4_7_7 + Choice_4_7_8 + Choice_4_7_9
#  = 1
#
# _C170: Choice_4_8_1 + Choice_4_8_2 + Choice_4_8_3 + Choice_4_8_4
#  + Choice_4_8_5 + Choice_4_8_6 + Choice_4_8_7 + Choice_4_8_8 + Choice_4_8_9
#  = 1
#
# _C171: Choice_4_9_1 + Choice_4_9_2 + Choice_4_9_3 + Choice_4_9_4
#  + Choice_4_9_5 + Choice_4_9_6 + Choice_4_9_7 + Choice_4_9_8 + Choice_4_9_9
#  = 1
#
# _C172: Choice_4_1_1 + Choice_4_2_1 + Choice_4_3_1 + Choice_4_4_1
#  + Choice_4_5_1 + Choice_4_6_1 + Choice_4_7_1 + Choice_4_8_1 + Choice_4_9_1
#  = 1
#
# _C173: Choice_4_1_2 + Choice_4_2_2 + Choice_4_3_2 + Choice_4_4_2
#  + Choice_4_5_2 + Choice_4_6_2 + Choice_4_7_2 + Choice_4_8_2 + Choice_4_9_2
#  = 1
#
# _C174: Choice_4_1_3 + Choice_4_2_3 + Choice_4_3_3 + Choice_4_4_3
#  + Choice_4_5_3 + Choice_4_6_3 + Choice_4_7_3 + Choice_4_8_3 + Choice_4_9_3
#  = 1
#
# _C175: Choice_4_1_4 + Choice_4_2_4 + Choice_4_3_4 + Choice_4_4_4
#  + Choice_4_5_4 + Choice_4_6_4 + Choice_4_7_4 + Choice_4_8_4 + Choice_4_9_4
#  = 1
#
# _C176: Choice_4_1_5 + Choice_4_2_5 + Choice_4_3_5 + Choice_4_4_5
#  + Choice_4_5_5 + Choice_4_6_5 + Choice_4_7_5 + Choice_4_8_5 + Choice_4_9_5
#  = 1
#
# _C177: Choice_4_1_6 + Choice_4_2_6 + Choice_4_3_6 + Choice_4_4_6
#  + Choice_4_5_6 + Choice_4_6_6 + Choice_4_7_6 + Choice_4_8_6 + Choice_4_9_6
#  = 1
#
# _C178: Choice_4_1_7 + Choice_4_2_7 + Choice_4_3_7 + Choice_4_4_7
#  + Choice_4_5_7 + Choice_4_6_7 + Choice_4_7_7 + Choice_4_8_7 + Choice_4_9_7
#  = 1
#
# _C179: Choice_4_1_8 + Choice_4_2_8 + Choice_4_3_8 + Choice_4_4_8
#  + Choice_4_5_8 + Choice_4_6_8 + Choice_4_7_8 + Choice_4_8_8 + Choice_4_9_8
#  = 1
#
# _C180: Choice_4_1_9 + Choice_4_2_9 + Choice_4_3_9 + Choice_4_4_9
#  + Choice_4_5_9 + Choice_4_6_9 + Choice_4_7_9 + Choice_4_8_9 + Choice_4_9_9
#  = 1
#
# _C181: Choice_4_1_1 + Choice_4_1_2 + Choice_4_1_3 + Choice_4_2_1
#  + Choice_4_2_2 + Choice_4_2_3 + Choice_4_3_1 + Choice_4_3_2 + Choice_4_3_3
#  = 1
#
# _C182: Choice_4_1_4 + Choice_4_1_5 + Choice_4_1_6 + Choice_4_2_4
#  + Choice_4_2_5 + Choice_4_2_6 + Choice_4_3_4 + Choice_4_3_5 + Choice_4_3_6
#  = 1
#
# _C183: Choice_4_1_7 + Choice_4_1_8 + Choice_4_1_9 + Choice_4_2_7
#  + Choice_4_2_8 + Choice_4_2_9 + Choice_4_3_7 + Choice_4_3_8 + Choice_4_3_9
#  = 1
#
# _C184: Choice_4_4_1 + Choice_4_4_2 + Choice_4_4_3 + Choice_4_5_1
#  + Choice_4_5_2 + Choice_4_5_3 + Choice_4_6_1 + Choice_4_6_2 + Choice_4_6_3
#  = 1
#
# _C185: Choice_4_4_4 + Choice_4_4_5 + Choice_4_4_6 + Choice_4_5_4
#  + Choice_4_5_5 + Choice_4_5_6 + Choice_4_6_4 + Choice_4_6_5 + Choice_4_6_6
#  = 1
#
# _C186: Choice_4_4_7 + Choice_4_4_8 + Choice_4_4_9 + Choice_4_5_7
#  + Choice_4_5_8 + Choice_4_5_9 + Choice_4_6_7 + Choice_4_6_8 + Choice_4_6_9
#  = 1
#
# _C187: Choice_4_7_1 + Choice_4_7_2 + Choice_4_7_3 + Choice_4_8_1
#  + Choice_4_8_2 + Choice_4_8_3 + Choice_4_9_1 + Choice_4_9_2 + Choice_4_9_3
#  = 1
#
# _C188: Choice_4_7_4 + Choice_4_7_5 + Choice_4_7_6 + Choice_4_8_4
#  + Choice_4_8_5 + Choice_4_8_6 + Choice_4_9_4 + Choice_4_9_5 + Choice_4_9_6
#  = 1
#
# _C189: Choice_4_7_7 + Choice_4_7_8 + Choice_4_7_9 + Choice_4_8_7
#  + Choice_4_8_8 + Choice_4_8_9 + Choice_4_9_7 + Choice_4_9_8 + Choice_4_9_9
#  = 1
#
# _C190: Choice_5_1_1 + Choice_5_1_2 + Choice_5_1_3 + Choice_5_1_4
#  + Choice_5_1_5 + Choice_5_1_6 + Choice_5_1_7 + Choice_5_1_8 + Choice_5_1_9
#  = 1
#
# _C191: Choice_5_2_1 + Choice_5_2_2 + Choice_5_2_3 + Choice_5_2_4
#  + Choice_5_2_5 + Choice_5_2_6 + Choice_5_2_7 + Choice_5_2_8 + Choice_5_2_9
#  = 1
#
# _C192: Choice_5_3_1 + Choice_5_3_2 + Choice_5_3_3 + Choice_5_3_4
#  + Choice_5_3_5 + Choice_5_3_6 + Choice_5_3_7 + Choice_5_3_8 + Choice_5_3_9
#  = 1
#
# _C193: Choice_5_4_1 + Choice_5_4_2 + Choice_5_4_3 + Choice_5_4_4
#  + Choice_5_4_5 + Choice_5_4_6 + Choice_5_4_7 + Choice_5_4_8 + Choice_5_4_9
#  = 1
#
# _C194: Choice_5_5_1 + Choice_5_5_2 + Choice_5_5_3 + Choice_5_5_4
#  + Choice_5_5_5 + Choice_5_5_6 + Choice_5_5_7 + Choice_5_5_8 + Choice_5_5_9
#  = 1
#
# _C195: Choice_5_6_1 + Choice_5_6_2 + Choice_5_6_3 + Choice_5_6_4
#  + Choice_5_6_5 + Choice_5_6_6 + Choice_5_6_7 + Choice_5_6_8 + Choice_5_6_9
#  = 1
#
# _C196: Choice_5_7_1 + Choice_5_7_2 + Choice_5_7_3 + Choice_5_7_4
#  + Choice_5_7_5 + Choice_5_7_6 + Choice_5_7_7 + Choice_5_7_8 + Choice_5_7_9
#  = 1
#
# _C197: Choice_5_8_1 + Choice_5_8_2 + Choice_5_8_3 + Choice_5_8_4
#  + Choice_5_8_5 + Choice_5_8_6 + Choice_5_8_7 + Choice_5_8_8 + Choice_5_8_9
#  = 1
#
# _C198: Choice_5_9_1 + Choice_5_9_2 + Choice_5_9_3 + Choice_5_9_4
#  + Choice_5_9_5 + Choice_5_9_6 + Choice_5_9_7 + Choice_5_9_8 + Choice_5_9_9
#  = 1
#
# _C199: Choice_5_1_1 + Choice_5_2_1 + Choice_5_3_1 + Choice_5_4_1
#  + Choice_5_5_1 + Choice_5_6_1 + Choice_5_7_1 + Choice_5_8_1 + Choice_5_9_1
#  = 1
#
# _C200: Choice_5_1_2 + Choice_5_2_2 + Choice_5_3_2 + Choice_5_4_2
#  + Choice_5_5_2 + Choice_5_6_2 + Choice_5_7_2 + Choice_5_8_2 + Choice_5_9_2
#  = 1
#
# _C201: Choice_5_1_3 + Choice_5_2_3 + Choice_5_3_3 + Choice_5_4_3
#  + Choice_5_5_3 + Choice_5_6_3 + Choice_5_7_3 + Choice_5_8_3 + Choice_5_9_3
#  = 1
#
# _C202: Choice_5_1_4 + Choice_5_2_4 + Choice_5_3_4 + Choice_5_4_4
#  + Choice_5_5_4 + Choice_5_6_4 + Choice_5_7_4 + Choice_5_8_4 + Choice_5_9_4
#  = 1
#
# _C203: Choice_5_1_5 + Choice_5_2_5 + Choice_5_3_5 + Choice_5_4_5
#  + Choice_5_5_5 + Choice_5_6_5 + Choice_5_7_5 + Choice_5_8_5 + Choice_5_9_5
#  = 1
#
# _C204: Choice_5_1_6 + Choice_5_2_6 + Choice_5_3_6 + Choice_5_4_6
#  + Choice_5_5_6 + Choice_5_6_6 + Choice_5_7_6 + Choice_5_8_6 + Choice_5_9_6
#  = 1
#
# _C205: Choice_5_1_7 + Choice_5_2_7 + Choice_5_3_7 + Choice_5_4_7
#  + Choice_5_5_7 + Choice_5_6_7 + Choice_5_7_7 + Choice_5_8_7 + Choice_5_9_7
#  = 1
#
# _C206: Choice_5_1_8 + Choice_5_2_8 + Choice_5_3_8 + Choice_5_4_8
#  + Choice_5_5_8 + Choice_5_6_8 + Choice_5_7_8 + Choice_5_8_8 + Choice_5_9_8
#  = 1
#
# _C207: Choice_5_1_9 + Choice_5_2_9 + Choice_5_3_9 + Choice_5_4_9
#  + Choice_5_5_9 + Choice_5_6_9 + Choice_5_7_9 + Choice_5_8_9 + Choice_5_9_9
#  = 1
#
# _C208: Choice_5_1_1 + Choice_5_1_2 + Choice_5_1_3 + Choice_5_2_1
#  + Choice_5_2_2 + Choice_5_2_3 + Choice_5_3_1 + Choice_5_3_2 + Choice_5_3_3
#  = 1
#
# _C209: Choice_5_1_4 + Choice_5_1_5 + Choice_5_1_6 + Choice_5_2_4
#  + Choice_5_2_5 + Choice_5_2_6 + Choice_5_3_4 + Choice_5_3_5 + Choice_5_3_6
#  = 1
#
# _C210: Choice_5_1_7 + Choice_5_1_8 + Choice_5_1_9 + Choice_5_2_7
#  + Choice_5_2_8 + Choice_5_2_9 + Choice_5_3_7 + Choice_5_3_8 + Choice_5_3_9
#  = 1
#
# _C211: Choice_5_4_1 + Choice_5_4_2 + Choice_5_4_3 + Choice_5_5_1
#  + Choice_5_5_2 + Choice_5_5_3 + Choice_5_6_1 + Choice_5_6_2 + Choice_5_6_3
#  = 1
#
# _C212: Choice_5_4_4 + Choice_5_4_5 + Choice_5_4_6 + Choice_5_5_4
#  + Choice_5_5_5 + Choice_5_5_6 + Choice_5_6_4 + Choice_5_6_5 + Choice_5_6_6
#  = 1
#
# _C213: Choice_5_4_7 + Choice_5_4_8 + Choice_5_4_9 + Choice_5_5_7
#  + Choice_5_5_8 + Choice_5_5_9 + Choice_5_6_7 + Choice_5_6_8 + Choice_5_6_9
#  = 1
#
# _C214: Choice_5_7_1 + Choice_5_7_2 + Choice_5_7_3 + Choice_5_8_1
#  + Choice_5_8_2 + Choice_5_8_3 + Choice_5_9_1 + Choice_5_9_2 + Choice_5_9_3
#  = 1
#
# _C215: Choice_5_7_4 + Choice_5_7_5 + Choice_5_7_6 + Choice_5_8_4
#  + Choice_5_8_5 + Choice_5_8_6 + Choice_5_9_4 + Choice_5_9_5 + Choice_5_9_6
#  = 1
#
# _C216: Choice_5_7_7 + Choice_5_7_8 + Choice_5_7_9 + Choice_5_8_7
#  + Choice_5_8_8 + Choice_5_8_9 + Choice_5_9_7 + Choice_5_9_8 + Choice_5_9_9
#  = 1
#
# _C217: Choice_6_1_1 + Choice_6_1_2 + Choice_6_1_3 + Choice_6_1_4
#  + Choice_6_1_5 + Choice_6_1_6 + Choice_6_1_7 + Choice_6_1_8 + Choice_6_1_9
#  = 1
#
# _C218: Choice_6_2_1 + Choice_6_2_2 + Choice_6_2_3 + Choice_6_2_4
#  + Choice_6_2_5 + Choice_6_2_6 + Choice_6_2_7 + Choice_6_2_8 + Choice_6_2_9
#  = 1
#
# _C219: Choice_6_3_1 + Choice_6_3_2 + Choice_6_3_3 + Choice_6_3_4
#  + Choice_6_3_5 + Choice_6_3_6 + Choice_6_3_7 + Choice_6_3_8 + Choice_6_3_9
#  = 1
#
# _C220: Choice_6_4_1 + Choice_6_4_2 + Choice_6_4_3 + Choice_6_4_4
#  + Choice_6_4_5 + Choice_6_4_6 + Choice_6_4_7 + Choice_6_4_8 + Choice_6_4_9
#  = 1
#
# _C221: Choice_6_5_1 + Choice_6_5_2 + Choice_6_5_3 + Choice_6_5_4
#  + Choice_6_5_5 + Choice_6_5_6 + Choice_6_5_7 + Choice_6_5_8 + Choice_6_5_9
#  = 1
#
# _C222: Choice_6_6_1 + Choice_6_6_2 + Choice_6_6_3 + Choice_6_6_4
#  + Choice_6_6_5 + Choice_6_6_6 + Choice_6_6_7 + Choice_6_6_8 + Choice_6_6_9
#  = 1
#
# _C223: Choice_6_7_1 + Choice_6_7_2 + Choice_6_7_3 + Choice_6_7_4
#  + Choice_6_7_5 + Choice_6_7_6 + Choice_6_7_7 + Choice_6_7_8 + Choice_6_7_9
#  = 1
#
# _C224: Choice_6_8_1 + Choice_6_8_2 + Choice_6_8_3 + Choice_6_8_4
#  + Choice_6_8_5 + Choice_6_8_6 + Choice_6_8_7 + Choice_6_8_8 + Choice_6_8_9
#  = 1
#
# _C225: Choice_6_9_1 + Choice_6_9_2 + Choice_6_9_3 + Choice_6_9_4
#  + Choice_6_9_5 + Choice_6_9_6 + Choice_6_9_7 + Choice_6_9_8 + Choice_6_9_9
#  = 1
#
# _C226: Choice_6_1_1 + Choice_6_2_1 + Choice_6_3_1 + Choice_6_4_1
#  + Choice_6_5_1 + Choice_6_6_1 + Choice_6_7_1 + Choice_6_8_1 + Choice_6_9_1
#  = 1
#
# _C227: Choice_6_1_2 + Choice_6_2_2 + Choice_6_3_2 + Choice_6_4_2
#  + Choice_6_5_2 + Choice_6_6_2 + Choice_6_7_2 + Choice_6_8_2 + Choice_6_9_2
#  = 1
#
# _C228: Choice_6_1_3 + Choice_6_2_3 + Choice_6_3_3 + Choice_6_4_3
#  + Choice_6_5_3 + Choice_6_6_3 + Choice_6_7_3 + Choice_6_8_3 + Choice_6_9_3
#  = 1
#
# _C229: Choice_6_1_4 + Choice_6_2_4 + Choice_6_3_4 + Choice_6_4_4
#  + Choice_6_5_4 + Choice_6_6_4 + Choice_6_7_4 + Choice_6_8_4 + Choice_6_9_4
#  = 1
#
# _C230: Choice_6_1_5 + Choice_6_2_5 + Choice_6_3_5 + Choice_6_4_5
#  + Choice_6_5_5 + Choice_6_6_5 + Choice_6_7_5 + Choice_6_8_5 + Choice_6_9_5
#  = 1
#
# _C231: Choice_6_1_6 + Choice_6_2_6 + Choice_6_3_6 + Choice_6_4_6
#  + Choice_6_5_6 + Choice_6_6_6 + Choice_6_7_6 + Choice_6_8_6 + Choice_6_9_6
#  = 1
#
# _C232: Choice_6_1_7 + Choice_6_2_7 + Choice_6_3_7 + Choice_6_4_7
#  + Choice_6_5_7 + Choice_6_6_7 + Choice_6_7_7 + Choice_6_8_7 + Choice_6_9_7
#  = 1
#
# _C233: Choice_6_1_8 + Choice_6_2_8 + Choice_6_3_8 + Choice_6_4_8
#  + Choice_6_5_8 + Choice_6_6_8 + Choice_6_7_8 + Choice_6_8_8 + Choice_6_9_8
#  = 1
#
# _C234: Choice_6_1_9 + Choice_6_2_9 + Choice_6_3_9 + Choice_6_4_9
#  + Choice_6_5_9 + Choice_6_6_9 + Choice_6_7_9 + Choice_6_8_9 + Choice_6_9_9
#  = 1
#
# _C235: Choice_6_1_1 + Choice_6_1_2 + Choice_6_1_3 + Choice_6_2_1
#  + Choice_6_2_2 + Choice_6_2_3 + Choice_6_3_1 + Choice_6_3_2 + Choice_6_3_3
#  = 1
#
# _C236: Choice_6_1_4 + Choice_6_1_5 + Choice_6_1_6 + Choice_6_2_4
#  + Choice_6_2_5 + Choice_6_2_6 + Choice_6_3_4 + Choice_6_3_5 + Choice_6_3_6
#  = 1
#
# _C237: Choice_6_1_7 + Choice_6_1_8 + Choice_6_1_9 + Choice_6_2_7
#  + Choice_6_2_8 + Choice_6_2_9 + Choice_6_3_7 + Choice_6_3_8 + Choice_6_3_9
#  = 1
#
# _C238: Choice_6_4_1 + Choice_6_4_2 + Choice_6_4_3 + Choice_6_5_1
#  + Choice_6_5_2 + Choice_6_5_3 + Choice_6_6_1 + Choice_6_6_2 + Choice_6_6_3
#  = 1
#
# _C239: Choice_6_4_4 + Choice_6_4_5 + Choice_6_4_6 + Choice_6_5_4
#  + Choice_6_5_5 + Choice_6_5_6 + Choice_6_6_4 + Choice_6_6_5 + Choice_6_6_6
#  = 1
#
# _C240: Choice_6_4_7 + Choice_6_4_8 + Choice_6_4_9 + Choice_6_5_7
#  + Choice_6_5_8 + Choice_6_5_9 + Choice_6_6_7 + Choice_6_6_8 + Choice_6_6_9
#  = 1
#
# _C241: Choice_6_7_1 + Choice_6_7_2 + Choice_6_7_3 + Choice_6_8_1
#  + Choice_6_8_2 + Choice_6_8_3 + Choice_6_9_1 + Choice_6_9_2 + Choice_6_9_3
#  = 1
#
# _C242: Choice_6_7_4 + Choice_6_7_5 + Choice_6_7_6 + Choice_6_8_4
#  + Choice_6_8_5 + Choice_6_8_6 + Choice_6_9_4 + Choice_6_9_5 + Choice_6_9_6
#  = 1
#
# _C243: Choice_6_7_7 + Choice_6_7_8 + Choice_6_7_9 + Choice_6_8_7
#  + Choice_6_8_8 + Choice_6_8_9 + Choice_6_9_7 + Choice_6_9_8 + Choice_6_9_9
#  = 1
#
# _C244: Choice_7_1_1 + Choice_7_1_2 + Choice_7_1_3 + Choice_7_1_4
#  + Choice_7_1_5 + Choice_7_1_6 + Choice_7_1_7 + Choice_7_1_8 + Choice_7_1_9
#  = 1
#
# _C245: Choice_7_2_1 + Choice_7_2_2 + Choice_7_2_3 + Choice_7_2_4
#  + Choice_7_2_5 + Choice_7_2_6 + Choice_7_2_7 + Choice_7_2_8 + Choice_7_2_9
#  = 1
#
# _C246: Choice_7_3_1 + Choice_7_3_2 + Choice_7_3_3 + Choice_7_3_4
#  + Choice_7_3_5 + Choice_7_3_6 + Choice_7_3_7 + Choice_7_3_8 + Choice_7_3_9
#  = 1
#
# _C247: Choice_7_4_1 + Choice_7_4_2 + Choice_7_4_3 + Choice_7_4_4
#  + Choice_7_4_5 + Choice_7_4_6 + Choice_7_4_7 + Choice_7_4_8 + Choice_7_4_9
#  = 1
#
# _C248: Choice_7_5_1 + Choice_7_5_2 + Choice_7_5_3 + Choice_7_5_4
#  + Choice_7_5_5 + Choice_7_5_6 + Choice_7_5_7 + Choice_7_5_8 + Choice_7_5_9
#  = 1
#
# _C249: Choice_7_6_1 + Choice_7_6_2 + Choice_7_6_3 + Choice_7_6_4
#  + Choice_7_6_5 + Choice_7_6_6 + Choice_7_6_7 + Choice_7_6_8 + Choice_7_6_9
#  = 1
#
# _C250: Choice_7_7_1 + Choice_7_7_2 + Choice_7_7_3 + Choice_7_7_4
#  + Choice_7_7_5 + Choice_7_7_6 + Choice_7_7_7 + Choice_7_7_8 + Choice_7_7_9
#  = 1
#
# _C251: Choice_7_8_1 + Choice_7_8_2 + Choice_7_8_3 + Choice_7_8_4
#  + Choice_7_8_5 + Choice_7_8_6 + Choice_7_8_7 + Choice_7_8_8 + Choice_7_8_9
#  = 1
#
# _C252: Choice_7_9_1 + Choice_7_9_2 + Choice_7_9_3 + Choice_7_9_4
#  + Choice_7_9_5 + Choice_7_9_6 + Choice_7_9_7 + Choice_7_9_8 + Choice_7_9_9
#  = 1
#
# _C253: Choice_7_1_1 + Choice_7_2_1 + Choice_7_3_1 + Choice_7_4_1
#  + Choice_7_5_1 + Choice_7_6_1 + Choice_7_7_1 + Choice_7_8_1 + Choice_7_9_1
#  = 1
#
# _C254: Choice_7_1_2 + Choice_7_2_2 + Choice_7_3_2 + Choice_7_4_2
#  + Choice_7_5_2 + Choice_7_6_2 + Choice_7_7_2 + Choice_7_8_2 + Choice_7_9_2
#  = 1
#
# _C255: Choice_7_1_3 + Choice_7_2_3 + Choice_7_3_3 + Choice_7_4_3
#  + Choice_7_5_3 + Choice_7_6_3 + Choice_7_7_3 + Choice_7_8_3 + Choice_7_9_3
#  = 1
#
# _C256: Choice_7_1_4 + Choice_7_2_4 + Choice_7_3_4 + Choice_7_4_4
#  + Choice_7_5_4 + Choice_7_6_4 + Choice_7_7_4 + Choice_7_8_4 + Choice_7_9_4
#  = 1
#
# _C257: Choice_7_1_5 + Choice_7_2_5 + Choice_7_3_5 + Choice_7_4_5
#  + Choice_7_5_5 + Choice_7_6_5 + Choice_7_7_5 + Choice_7_8_5 + Choice_7_9_5
#  = 1
#
# _C258: Choice_7_1_6 + Choice_7_2_6 + Choice_7_3_6 + Choice_7_4_6
#  + Choice_7_5_6 + Choice_7_6_6 + Choice_7_7_6 + Choice_7_8_6 + Choice_7_9_6
#  = 1
#
# _C259: Choice_7_1_7 + Choice_7_2_7 + Choice_7_3_7 + Choice_7_4_7
#  + Choice_7_5_7 + Choice_7_6_7 + Choice_7_7_7 + Choice_7_8_7 + Choice_7_9_7
#  = 1
#
# _C260: Choice_7_1_8 + Choice_7_2_8 + Choice_7_3_8 + Choice_7_4_8
#  + Choice_7_5_8 + Choice_7_6_8 + Choice_7_7_8 + Choice_7_8_8 + Choice_7_9_8
#  = 1
#
# _C261: Choice_7_1_9 + Choice_7_2_9 + Choice_7_3_9 + Choice_7_4_9
#  + Choice_7_5_9 + Choice_7_6_9 + Choice_7_7_9 + Choice_7_8_9 + Choice_7_9_9
#  = 1
#
# _C262: Choice_7_1_1 + Choice_7_1_2 + Choice_7_1_3 + Choice_7_2_1
#  + Choice_7_2_2 + Choice_7_2_3 + Choice_7_3_1 + Choice_7_3_2 + Choice_7_3_3
#  = 1
#
# _C263: Choice_7_1_4 + Choice_7_1_5 + Choice_7_1_6 + Choice_7_2_4
#  + Choice_7_2_5 + Choice_7_2_6 + Choice_7_3_4 + Choice_7_3_5 + Choice_7_3_6
#  = 1
#
# _C264: Choice_7_1_7 + Choice_7_1_8 + Choice_7_1_9 + Choice_7_2_7
#  + Choice_7_2_8 + Choice_7_2_9 + Choice_7_3_7 + Choice_7_3_8 + Choice_7_3_9
#  = 1
#
# _C265: Choice_7_4_1 + Choice_7_4_2 + Choice_7_4_3 + Choice_7_5_1
#  + Choice_7_5_2 + Choice_7_5_3 + Choice_7_6_1 + Choice_7_6_2 + Choice_7_6_3
#  = 1
#
# _C266: Choice_7_4_4 + Choice_7_4_5 + Choice_7_4_6 + Choice_7_5_4
#  + Choice_7_5_5 + Choice_7_5_6 + Choice_7_6_4 + Choice_7_6_5 + Choice_7_6_6
#  = 1
#
# _C267: Choice_7_4_7 + Choice_7_4_8 + Choice_7_4_9 + Choice_7_5_7
#  + Choice_7_5_8 + Choice_7_5_9 + Choice_7_6_7 + Choice_7_6_8 + Choice_7_6_9
#  = 1
#
# _C268: Choice_7_7_1 + Choice_7_7_2 + Choice_7_7_3 + Choice_7_8_1
#  + Choice_7_8_2 + Choice_7_8_3 + Choice_7_9_1 + Choice_7_9_2 + Choice_7_9_3
#  = 1
#
# _C269: Choice_7_7_4 + Choice_7_7_5 + Choice_7_7_6 + Choice_7_8_4
#  + Choice_7_8_5 + Choice_7_8_6 + Choice_7_9_4 + Choice_7_9_5 + Choice_7_9_6
#  = 1
#
# _C270: Choice_7_7_7 + Choice_7_7_8 + Choice_7_7_9 + Choice_7_8_7
#  + Choice_7_8_8 + Choice_7_8_9 + Choice_7_9_7 + Choice_7_9_8 + Choice_7_9_9
#  = 1
#
# _C271: Choice_8_1_1 + Choice_8_1_2 + Choice_8_1_3 + Choice_8_1_4
#  + Choice_8_1_5 + Choice_8_1_6 + Choice_8_1_7 + Choice_8_1_8 + Choice_8_1_9
#  = 1
#
# _C272: Choice_8_2_1 + Choice_8_2_2 + Choice_8_2_3 + Choice_8_2_4
#  + Choice_8_2_5 + Choice_8_2_6 + Choice_8_2_7 + Choice_8_2_8 + Choice_8_2_9
#  = 1
#
# _C273: Choice_8_3_1 + Choice_8_3_2 + Choice_8_3_3 + Choice_8_3_4
#  + Choice_8_3_5 + Choice_8_3_6 + Choice_8_3_7 + Choice_8_3_8 + Choice_8_3_9
#  = 1
#
# _C274: Choice_8_4_1 + Choice_8_4_2 + Choice_8_4_3 + Choice_8_4_4
#  + Choice_8_4_5 + Choice_8_4_6 + Choice_8_4_7 + Choice_8_4_8 + Choice_8_4_9
#  = 1
#
# _C275: Choice_8_5_1 + Choice_8_5_2 + Choice_8_5_3 + Choice_8_5_4
#  + Choice_8_5_5 + Choice_8_5_6 + Choice_8_5_7 + Choice_8_5_8 + Choice_8_5_9
#  = 1
#
# _C276: Choice_8_6_1 + Choice_8_6_2 + Choice_8_6_3 + Choice_8_6_4
#  + Choice_8_6_5 + Choice_8_6_6 + Choice_8_6_7 + Choice_8_6_8 + Choice_8_6_9
#  = 1
#
# _C277: Choice_8_7_1 + Choice_8_7_2 + Choice_8_7_3 + Choice_8_7_4
#  + Choice_8_7_5 + Choice_8_7_6 + Choice_8_7_7 + Choice_8_7_8 + Choice_8_7_9
#  = 1
#
# _C278: Choice_8_8_1 + Choice_8_8_2 + Choice_8_8_3 + Choice_8_8_4
#  + Choice_8_8_5 + Choice_8_8_6 + Choice_8_8_7 + Choice_8_8_8 + Choice_8_8_9
#  = 1
#
# _C279: Choice_8_9_1 + Choice_8_9_2 + Choice_8_9_3 + Choice_8_9_4
#  + Choice_8_9_5 + Choice_8_9_6 + Choice_8_9_7 + Choice_8_9_8 + Choice_8_9_9
#  = 1
#
# _C280: Choice_8_1_1 + Choice_8_2_1 + Choice_8_3_1 + Choice_8_4_1
#  + Choice_8_5_1 + Choice_8_6_1 + Choice_8_7_1 + Choice_8_8_1 + Choice_8_9_1
#  = 1
#
# _C281: Choice_8_1_2 + Choice_8_2_2 + Choice_8_3_2 + Choice_8_4_2
#  + Choice_8_5_2 + Choice_8_6_2 + Choice_8_7_2 + Choice_8_8_2 + Choice_8_9_2
#  = 1
#
# _C282: Choice_8_1_3 + Choice_8_2_3 + Choice_8_3_3 + Choice_8_4_3
#  + Choice_8_5_3 + Choice_8_6_3 + Choice_8_7_3 + Choice_8_8_3 + Choice_8_9_3
#  = 1
#
# _C283: Choice_8_1_4 + Choice_8_2_4 + Choice_8_3_4 + Choice_8_4_4
#  + Choice_8_5_4 + Choice_8_6_4 + Choice_8_7_4 + Choice_8_8_4 + Choice_8_9_4
#  = 1
#
# _C284: Choice_8_1_5 + Choice_8_2_5 + Choice_8_3_5 + Choice_8_4_5
#  + Choice_8_5_5 + Choice_8_6_5 + Choice_8_7_5 + Choice_8_8_5 + Choice_8_9_5
#  = 1
#
# _C285: Choice_8_1_6 + Choice_8_2_6 + Choice_8_3_6 + Choice_8_4_6
#  + Choice_8_5_6 + Choice_8_6_6 + Choice_8_7_6 + Choice_8_8_6 + Choice_8_9_6
#  = 1
#
# _C286: Choice_8_1_7 + Choice_8_2_7 + Choice_8_3_7 + Choice_8_4_7
#  + Choice_8_5_7 + Choice_8_6_7 + Choice_8_7_7 + Choice_8_8_7 + Choice_8_9_7
#  = 1
#
# _C287: Choice_8_1_8 + Choice_8_2_8 + Choice_8_3_8 + Choice_8_4_8
#  + Choice_8_5_8 + Choice_8_6_8 + Choice_8_7_8 + Choice_8_8_8 + Choice_8_9_8
#  = 1
#
# _C288: Choice_8_1_9 + Choice_8_2_9 + Choice_8_3_9 + Choice_8_4_9
#  + Choice_8_5_9 + Choice_8_6_9 + Choice_8_7_9 + Choice_8_8_9 + Choice_8_9_9
#  = 1
#
# _C289: Choice_8_1_1 + Choice_8_1_2 + Choice_8_1_3 + Choice_8_2_1
#  + Choice_8_2_2 + Choice_8_2_3 + Choice_8_3_1 + Choice_8_3_2 + Choice_8_3_3
#  = 1
#
# _C290: Choice_8_1_4 + Choice_8_1_5 + Choice_8_1_6 + Choice_8_2_4
#  + Choice_8_2_5 + Choice_8_2_6 + Choice_8_3_4 + Choice_8_3_5 + Choice_8_3_6
#  = 1
#
# _C291: Choice_8_1_7 + Choice_8_1_8 + Choice_8_1_9 + Choice_8_2_7
#  + Choice_8_2_8 + Choice_8_2_9 + Choice_8_3_7 + Choice_8_3_8 + Choice_8_3_9
#  = 1
#
# _C292: Choice_8_4_1 + Choice_8_4_2 + Choice_8_4_3 + Choice_8_5_1
#  + Choice_8_5_2 + Choice_8_5_3 + Choice_8_6_1 + Choice_8_6_2 + Choice_8_6_3
#  = 1
#
# _C293: Choice_8_4_4 + Choice_8_4_5 + Choice_8_4_6 + Choice_8_5_4
#  + Choice_8_5_5 + Choice_8_5_6 + Choice_8_6_4 + Choice_8_6_5 + Choice_8_6_6
#  = 1
#
# _C294: Choice_8_4_7 + Choice_8_4_8 + Choice_8_4_9 + Choice_8_5_7
#  + Choice_8_5_8 + Choice_8_5_9 + Choice_8_6_7 + Choice_8_6_8 + Choice_8_6_9
#  = 1
#
# _C295: Choice_8_7_1 + Choice_8_7_2 + Choice_8_7_3 + Choice_8_8_1
#  + Choice_8_8_2 + Choice_8_8_3 + Choice_8_9_1 + Choice_8_9_2 + Choice_8_9_3
#  = 1
#
# _C296: Choice_8_7_4 + Choice_8_7_5 + Choice_8_7_6 + Choice_8_8_4
#  + Choice_8_8_5 + Choice_8_8_6 + Choice_8_9_4 + Choice_8_9_5 + Choice_8_9_6
#  = 1
#
# _C297: Choice_8_7_7 + Choice_8_7_8 + Choice_8_7_9 + Choice_8_8_7
#  + Choice_8_8_8 + Choice_8_8_9 + Choice_8_9_7 + Choice_8_9_8 + Choice_8_9_9
#  = 1
#
# _C298: Choice_9_1_1 + Choice_9_1_2 + Choice_9_1_3 + Choice_9_1_4
#  + Choice_9_1_5 + Choice_9_1_6 + Choice_9_1_7 + Choice_9_1_8 + Choice_9_1_9
#  = 1
#
# _C299: Choice_9_2_1 + Choice_9_2_2 + Choice_9_2_3 + Choice_9_2_4
#  + Choice_9_2_5 + Choice_9_2_6 + Choice_9_2_7 + Choice_9_2_8 + Choice_9_2_9
#  = 1
#
# _C300: Choice_9_3_1 + Choice_9_3_2 + Choice_9_3_3 + Choice_9_3_4
#  + Choice_9_3_5 + Choice_9_3_6 + Choice_9_3_7 + Choice_9_3_8 + Choice_9_3_9
#  = 1
#
# _C301: Choice_9_4_1 + Choice_9_4_2 + Choice_9_4_3 + Choice_9_4_4
#  + Choice_9_4_5 + Choice_9_4_6 + Choice_9_4_7 + Choice_9_4_8 + Choice_9_4_9
#  = 1
#
# _C302: Choice_9_5_1 + Choice_9_5_2 + Choice_9_5_3 + Choice_9_5_4
#  + Choice_9_5_5 + Choice_9_5_6 + Choice_9_5_7 + Choice_9_5_8 + Choice_9_5_9
#  = 1
#
# _C303: Choice_9_6_1 + Choice_9_6_2 + Choice_9_6_3 + Choice_9_6_4
#  + Choice_9_6_5 + Choice_9_6_6 + Choice_9_6_7 + Choice_9_6_8 + Choice_9_6_9
#  = 1
#
# _C304: Choice_9_7_1 + Choice_9_7_2 + Choice_9_7_3 + Choice_9_7_4
#  + Choice_9_7_5 + Choice_9_7_6 + Choice_9_7_7 + Choice_9_7_8 + Choice_9_7_9
#  = 1
#
# _C305: Choice_9_8_1 + Choice_9_8_2 + Choice_9_8_3 + Choice_9_8_4
#  + Choice_9_8_5 + Choice_9_8_6 + Choice_9_8_7 + Choice_9_8_8 + Choice_9_8_9
#  = 1
#
# _C306: Choice_9_9_1 + Choice_9_9_2 + Choice_9_9_3 + Choice_9_9_4
#  + Choice_9_9_5 + Choice_9_9_6 + Choice_9_9_7 + Choice_9_9_8 + Choice_9_9_9
#  = 1
#
# _C307: Choice_9_1_1 + Choice_9_2_1 + Choice_9_3_1 + Choice_9_4_1
#  + Choice_9_5_1 + Choice_9_6_1 + Choice_9_7_1 + Choice_9_8_1 + Choice_9_9_1
#  = 1
#
# _C308: Choice_9_1_2 + Choice_9_2_2 + Choice_9_3_2 + Choice_9_4_2
#  + Choice_9_5_2 + Choice_9_6_2 + Choice_9_7_2 + Choice_9_8_2 + Choice_9_9_2
#  = 1
#
# _C309: Choice_9_1_3 + Choice_9_2_3 + Choice_9_3_3 + Choice_9_4_3
#  + Choice_9_5_3 + Choice_9_6_3 + Choice_9_7_3 + Choice_9_8_3 + Choice_9_9_3
#  = 1
#
# _C310: Choice_9_1_4 + Choice_9_2_4 + Choice_9_3_4 + Choice_9_4_4
#  + Choice_9_5_4 + Choice_9_6_4 + Choice_9_7_4 + Choice_9_8_4 + Choice_9_9_4
#  = 1
#
# _C311: Choice_9_1_5 + Choice_9_2_5 + Choice_9_3_5 + Choice_9_4_5
#  + Choice_9_5_5 + Choice_9_6_5 + Choice_9_7_5 + Choice_9_8_5 + Choice_9_9_5
#  = 1
#
# _C312: Choice_9_1_6 + Choice_9_2_6 + Choice_9_3_6 + Choice_9_4_6
#  + Choice_9_5_6 + Choice_9_6_6 + Choice_9_7_6 + Choice_9_8_6 + Choice_9_9_6
#  = 1
#
# _C313: Choice_9_1_7 + Choice_9_2_7 + Choice_9_3_7 + Choice_9_4_7
#  + Choice_9_5_7 + Choice_9_6_7 + Choice_9_7_7 + Choice_9_8_7 + Choice_9_9_7
#  = 1
#
# _C314: Choice_9_1_8 + Choice_9_2_8 + Choice_9_3_8 + Choice_9_4_8
#  + Choice_9_5_8 + Choice_9_6_8 + Choice_9_7_8 + Choice_9_8_8 + Choice_9_9_8
#  = 1
#
# _C315: Choice_9_1_9 + Choice_9_2_9 + Choice_9_3_9 + Choice_9_4_9
#  + Choice_9_5_9 + Choice_9_6_9 + Choice_9_7_9 + Choice_9_8_9 + Choice_9_9_9
#  = 1
#
# _C316: Choice_9_1_1 + Choice_9_1_2 + Choice_9_1_3 + Choice_9_2_1
#  + Choice_9_2_2 + Choice_9_2_3 + Choice_9_3_1 + Choice_9_3_2 + Choice_9_3_3
#  = 1
#
# _C317: Choice_9_1_4 + Choice_9_1_5 + Choice_9_1_6 + Choice_9_2_4
#  + Choice_9_2_5 + Choice_9_2_6 + Choice_9_3_4 + Choice_9_3_5 + Choice_9_3_6
#  = 1
#
# _C318: Choice_9_1_7 + Choice_9_1_8 + Choice_9_1_9 + Choice_9_2_7
#  + Choice_9_2_8 + Choice_9_2_9 + Choice_9_3_7 + Choice_9_3_8 + Choice_9_3_9
#  = 1
#
# _C319: Choice_9_4_1 + Choice_9_4_2 + Choice_9_4_3 + Choice_9_5_1
#  + Choice_9_5_2 + Choice_9_5_3 + Choice_9_6_1 + Choice_9_6_2 + Choice_9_6_3
#  = 1
#
# _C320: Choice_9_4_4 + Choice_9_4_5 + Choice_9_4_6 + Choice_9_5_4
#  + Choice_9_5_5 + Choice_9_5_6 + Choice_9_6_4 + Choice_9_6_5 + Choice_9_6_6
#  = 1
#
# _C321: Choice_9_4_7 + Choice_9_4_8 + Choice_9_4_9 + Choice_9_5_7
#  + Choice_9_5_8 + Choice_9_5_9 + Choice_9_6_7 + Choice_9_6_8 + Choice_9_6_9
#  = 1
#
# _C322: Choice_9_7_1 + Choice_9_7_2 + Choice_9_7_3 + Choice_9_8_1
#  + Choice_9_8_2 + Choice_9_8_3 + Choice_9_9_1 + Choice_9_9_2 + Choice_9_9_3
#  = 1
#
# _C323: Choice_9_7_4 + Choice_9_7_5 + Choice_9_7_6 + Choice_9_8_4
#  + Choice_9_8_5 + Choice_9_8_6 + Choice_9_9_4 + Choice_9_9_5 + Choice_9_9_6
#  = 1
#
# _C324: Choice_9_7_7 + Choice_9_7_8 + Choice_9_7_9 + Choice_9_8_7
#  + Choice_9_8_8 + Choice_9_8_9 + Choice_9_9_7 + Choice_9_9_8 + Choice_9_9_9
#  = 1
#
# _C325: Choice_5_1_1 = 1
#
# _C326: Choice_6_2_1 = 1
#
# _C327: Choice_8_4_1 = 1
#
# _C328: Choice_4_5_1 = 1
#
# _C329: Choice_7_6_1 = 1
#
# _C330: Choice_3_1_2 = 1
#
# _C331: Choice_9_3_2 = 1
#
# _C332: Choice_6_7_2 = 1
#
# _C333: Choice_8_3_3 = 1
#
# _C334: Choice_1_2_4 = 1
#
# _C335: Choice_8_5_4 = 1
#
# _C336: Choice_4_8_4 = 1
#
# _C337: Choice_7_1_5 = 1
#
# _C338: Choice_9_2_5 = 1
#
# _C339: Choice_6_4_5 = 1
#
# _C340: Choice_2_6_5 = 1
#
# _C341: Choice_1_8_5 = 1
#
# _C342: Choice_8_9_5 = 1
#
# _C343: Choice_5_2_6 = 1
#
# _C344: Choice_3_5_6 = 1
#
# _C345: Choice_9_8_6 = 1
#
# ...
# 0 <= Choice_3_6_7 <= 1 Integer
# 0 <= Choice_3_6_8 <= 1 Integer
# 0 <= Choice_3_6_9 <= 1 Integer
# 0 <= Choice_3_7_1 <= 1 Integer
# 0 <= Choice_3_7_2 <= 1 Integer
# 0 <= Choice_3_7_3 <= 1 Integer
# 0 <= Choice_3_7_4 <= 1 Integer
# 0 <= Choice_3_7_5 <= 1 Integer
# 0 <= Choice_3_7_6 <= 1 Integer
# 0 <= Choice_3_7_7 <= 1 Integer
# 0 <= Choice_3_7_8 <= 1 Integer
# 0 <= Choice_3_7_9 <= 1 Integer
# 0 <= Choice_3_8_1 <= 1 Integer
# 0 <= Choice_3_8_2 <= 1 Integer
# 0 <= Choice_3_8_3 <= 1 Integer
# 0 <= Choice_3_8_4 <= 1 Integer
# 0 <= Choice_3_8_5 <= 1 Integer
# 0 <= Choice_3_8_6 <= 1 Integer
# 0 <= Choice_3_8_7 <= 1 Integer
# 0 <= Choice_3_8_8 <= 1 Integer
# 0 <= Choice_3_8_9 <= 1 Integer
# 0 <= Choice_3_9_1 <= 1 Integer
# 0 <= Choice_3_9_2 <= 1 Integer
# 0 <= Choice_3_9_3 <= 1 Integer
# 0 <= Choice_3_9_4 <= 1 Integer
# 0 <= Choice_3_9_5 <= 1 Integer
# 0 <= Choice_3_9_6 <= 1 Integer
# 0 <= Choice_3_9_7 <= 1 Integer
# 0 <= Choice_3_9_8 <= 1 Integer
# 0 <= Choice_3_9_9 <= 1 Integer
# 0 <= Choice_4_1_1 <= 1 Integer
# 0 <= Choice_4_1_2 <= 1 Integer
# 0 <= Choice_4_1_3 <= 1 Integer
# 0 <= Choice_4_1_4 <= 1 Integer
# 0 <= Choice_4_1_5 <= 1 Integer
# 0 <= Choice_4_1_6 <= 1 Integer
# 0 <= Choice_4_1_7 <= 1 Integer
# 0 <= Choice_4_1_8 <= 1 Integer
# 0 <= Choice_4_1_9 <= 1 Integer
# 0 <= Choice_4_2_1 <= 1 Integer
# 0 <= Choice_4_2_2 <= 1 Integer
# 0 <= Choice_4_2_3 <= 1 Integer
# 0 <= Choice_4_2_4 <= 1 Integer
# 0 <= Choice_4_2_5 <= 1 Integer
# 0 <= Choice_4_2_6 <= 1 Integer
# 0 <= Choice_4_2_7 <= 1 Integer
# 0 <= Choice_4_2_8 <= 1 Integer
# 0 <= Choice_4_2_9 <= 1 Integer
# 0 <= Choice_4_3_1 <= 1 Integer
# 0 <= Choice_4_3_2 <= 1 Integer
# 0 <= Choice_4_3_3 <= 1 Integer
# 0 <= Choice_4_3_4 <= 1 Integer
# 0 <= Choice_4_3_5 <= 1 Integer
# 0 <= Choice_4_3_6 <= 1 Integer
# 0 <= Choice_4_3_7 <= 1 Integer
# 0 <= Choice_4_3_8 <= 1 Integer
# 0 <= Choice_4_3_9 <= 1 Integer
# 0 <= Choice_4_4_1 <= 1 Integer
# 0 <= Choice_4_4_2 <= 1 Integer
# 0 <= Choice_4_4_3 <= 1 Integer
# 0 <= Choice_4_4_4 <= 1 Integer
# 0 <= Choice_4_4_5 <= 1 Integer
# 0 <= Choice_4_4_6 <= 1 Integer
# 0 <= Choice_4_4_7 <= 1 Integer
# 0 <= Choice_4_4_8 <= 1 Integer
# 0 <= Choice_4_4_9 <= 1 Integer
# 0 <= Choice_4_5_1 <= 1 Integer
# 0 <= Choice_4_5_2 <= 1 Integer
# 0 <= Choice_4_5_3 <= 1 Integer
# 0 <= Choice_4_5_4 <= 1 Integer
# 0 <= Choice_4_5_5 <= 1 Integer
# 0 <= Choice_4_5_6 <= 1 Integer
# 0 <= Choice_4_5_7 <= 1 Integer
# 0 <= Choice_4_5_8 <= 1 Integer
# 0 <= Choice_4_5_9 <= 1 Integer
# 0 <= Choice_4_6_1 <= 1 Integer
# 0 <= Choice_4_6_2 <= 1 Integer
# 0 <= Choice_4_6_3 <= 1 Integer
# 0 <= Choice_4_6_4 <= 1 Integer
# 0 <= Choice_4_6_5 <= 1 Integer
# 0 <= Choice_4_6_6 <= 1 Integer
# 0 <= Choice_4_6_7 <= 1 Integer
# 0 <= Choice_4_6_8 <= 1 Integer
# 0 <= Choice_4_6_9 <= 1 Integer
# 0 <= Choice_4_7_1 <= 1 Integer
# 0 <= Choice_4_7_2 <= 1 Integer
# 0 <= Choice_4_7_3 <= 1 Integer
# 0 <= Choice_4_7_4 <= 1 Integer
# 0 <= Choice_4_7_5 <= 1 Integer
# 0 <= Choice_4_7_6 <= 1 Integer
# 0 <= Choice_4_7_7 <= 1 Integer
# 0 <= Choice_4_7_8 <= 1 Integer
# 0 <= Choice_4_7_9 <= 1 Integer
# 0 <= Choice_4_8_1 <= 1 Integer
# 0 <= Choice_4_8_2 <= 1 Integer
# 0 <= Choice_4_8_3 <= 1 Integer
# 0 <= Choice_4_8_4 <= 1 Integer
# 0 <= Choice_4_8_5 <= 1 Integer
# 0 <= Choice_4_8_6 <= 1 Integer
# 0 <= Choice_4_8_7 <= 1 Integer
# 0 <= Choice_4_8_8 <= 1 Integer
# 0 <= Choice_4_8_9 <= 1 Integer
# 0 <= Choice_4_9_1 <= 1 Integer
# 0 <= Choice_4_9_2 <= 1 Integer
# 0 <= Choice_4_9_3 <= 1 Integer
# 0 <= Choice_4_9_4 <= 1 Integer
# 0 <= Choice_4_9_5 <= 1 Integer
# 0 <= Choice_4_9_6 <= 1 Integer
# 0 <= Choice_4_9_7 <= 1 Integer
# 0 <= Choice_4_9_8 <= 1 Integer
# 0 <= Choice_4_9_9 <= 1 Integer
# 0 <= Choice_5_1_1 <= 1 Integer
# 0 <= Choice_5_1_2 <= 1 Integer
# 0 <= Choice_5_1_3 <= 1 Integer
# 0 <= Choice_5_1_4 <= 1 Integer
# 0 <= Choice_5_1_5 <= 1 Integer
# 0 <= Choice_5_1_6 <= 1 Integer
# 0 <= Choice_5_1_7 <= 1 Integer
# 0 <= Choice_5_1_8 <= 1 Integer
# 0 <= Choice_5_1_9 <= 1 Integer
# 0 <= Choice_5_2_1 <= 1 Integer
# 0 <= Choice_5_2_2 <= 1 Integer
# 0 <= Choice_5_2_3 <= 1 Integer
# 0 <= Choice_5_2_4 <= 1 Integer
# 0 <= Choice_5_2_5 <= 1 Integer
# 0 <= Choice_5_2_6 <= 1 Integer
# 0 <= Choice_5_2_7 <= 1 Integer
# 0 <= Choice_5_2_8 <= 1 Integer
# 0 <= Choice_5_2_9 <= 1 Integer
# 0 <= Choice_5_3_1 <= 1 Integer
# 0 <= Choice_5_3_2 <= 1 Integer
# 0 <= Choice_5_3_3 <= 1 Integer
# 0 <= Choice_5_3_4 <= 1 Integer
# 0 <= Choice_5_3_5 <= 1 Integer
# 0 <= Choice_5_3_6 <= 1 Integer
# 0 <= Choice_5_3_7 <= 1 Integer
# 0 <= Choice_5_3_8 <= 1 Integer
# 0 <= Choice_5_3_9 <= 1 Integer
# 0 <= Choice_5_4_1 <= 1 Integer
# 0 <= Choice_5_4_2 <= 1 Integer
# 0 <= Choice_5_4_3 <= 1 Integer
# 0 <= Choice_5_4_4 <= 1 Integer
# 0 <= Choice_5_4_5 <= 1 Integer
# 0 <= Choice_5_4_6 <= 1 Integer
# 0 <= Choice_5_4_7 <= 1 Integer
# 0 <= Choice_5_4_8 <= 1 Integer
# 0 <= Choice_5_4_9 <= 1 Integer
# 0 <= Choice_5_5_1 <= 1 Integer
# 0 <= Choice_5_5_2 <= 1 Integer
# 0 <= Choice_5_5_3 <= 1 Integer
# 0 <= Choice_5_5_4 <= 1 Integer
# 0 <= Choice_5_5_5 <= 1 Integer
# 0 <= Choice_5_5_6 <= 1 Integer
# 0 <= Choice_5_5_7 <= 1 Integer
# 0 <= Choice_5_5_8 <= 1 Integer
# 0 <= Choice_5_5_9 <= 1 Integer
# 0 <= Choice_5_6_1 <= 1 Integer
# 0 <= Choice_5_6_2 <= 1 Integer
# 0 <= Choice_5_6_3 <= 1 Integer
# 0 <= Choice_5_6_4 <= 1 Integer
# 0 <= Choice_5_6_5 <= 1 Integer
# 0 <= Choice_5_6_6 <= 1 Integer
# 0 <= Choice_5_6_7 <= 1 Integer
# 0 <= Choice_5_6_8 <= 1 Integer
# 0 <= Choice_5_6_9 <= 1 Integer
# 0 <= Choice_5_7_1 <= 1 Integer
# 0 <= Choice_5_7_2 <= 1 Integer
# 0 <= Choice_5_7_3 <= 1 Integer
# 0 <= Choice_5_7_4 <= 1 Integer
# 0 <= Choice_5_7_5 <= 1 Integer
# 0 <= Choice_5_7_6 <= 1 Integer
# 0 <= Choice_5_7_7 <= 1 Integer
# 0 <= Choice_5_7_8 <= 1 Integer
# 0 <= Choice_5_7_9 <= 1 Integer
# 0 <= Choice_5_8_1 <= 1 Integer
# 0 <= Choice_5_8_2 <= 1 Integer
# 0 <= Choice_5_8_3 <= 1 Integer
# 0 <= Choice_5_8_4 <= 1 Integer
# 0 <= Choice_5_8_5 <= 1 Integer
# 0 <= Choice_5_8_6 <= 1 Integer
# 0 <= Choice_5_8_7 <= 1 Integer
# 0 <= Choice_5_8_8 <= 1 Integer
# 0 <= Choice_5_8_9 <= 1 Integer
# 0 <= Choice_5_9_1 <= 1 Integer
# 0 <= Choice_5_9_2 <= 1 Integer
# 0 <= Choice_5_9_3 <= 1 Integer
# 0 <= Choice_5_9_4 <= 1 Integer
# 0 <= Choice_5_9_5 <= 1 Integer
# 0 <= Choice_5_9_6 <= 1 Integer
# 0 <= Choice_5_9_7 <= 1 Integer
# 0 <= Choice_5_9_8 <= 1 Integer
# 0 <= Choice_5_9_9 <= 1 Integer
# 0 <= Choice_6_1_1 <= 1 Integer
# 0 <= Choice_6_1_2 <= 1 Integer
# 0 <= Choice_6_1_3 <= 1 Integer
# 0 <= Choice_6_1_4 <= 1 Integer
# 0 <= Choice_6_1_5 <= 1 Integer
# 0 <= Choice_6_1_6 <= 1 Integer
# 0 <= Choice_6_1_7 <= 1 Integer
# 0 <= Choice_6_1_8 <= 1 Integer
# 0 <= Choice_6_1_9 <= 1 Integer
# 0 <= Choice_6_2_1 <= 1 Integer
# 0 <= Choice_6_2_2 <= 1 Integer
# 0 <= Choice_6_2_3 <= 1 Integer
# 0 <= Choice_6_2_4 <= 1 Integer
# 0 <= Choice_6_2_5 <= 1 Integer
# 0 <= Choice_6_2_6 <= 1 Integer
# 0 <= Choice_6_2_7 <= 1 Integer
# 0 <= Choice_6_2_8 <= 1 Integer
# 0 <= Choice_6_2_9 <= 1 Integer
# 0 <= Choice_6_3_1 <= 1 Integer
# 0 <= Choice_6_3_2 <= 1 Integer
# 0 <= Choice_6_3_3 <= 1 Integer
# 0 <= Choice_6_3_4 <= 1 Integer
# 0 <= Choice_6_3_5 <= 1 Integer
# 0 <= Choice_6_3_6 <= 1 Integer
# 0 <= Choice_6_3_7 <= 1 Integer
# 0 <= Choice_6_3_8 <= 1 Integer
# 0 <= Choice_6_3_9 <= 1 Integer
# 0 <= Choice_6_4_1 <= 1 Integer
# 0 <= Choice_6_4_2 <= 1 Integer
# 0 <= Choice_6_4_3 <= 1 Integer
# 0 <= Choice_6_4_4 <= 1 Integer
# 0 <= Choice_6_4_5 <= 1 Integer
# 0 <= Choice_6_4_6 <= 1 Integer
# 0 <= Choice_6_4_7 <= 1 Integer
# 0 <= Choice_6_4_8 <= 1 Integer
# 0 <= Choice_6_4_9 <= 1 Integer
# 0 <= Choice_6_5_1 <= 1 Integer
# 0 <= Choice_6_5_2 <= 1 Integer
# 0 <= Choice_6_5_3 <= 1 Integer
# 0 <= Choice_6_5_4 <= 1 Integer
# 0 <= Choice_6_5_5 <= 1 Integer
# 0 <= Choice_6_5_6 <= 1 Integer
# 0 <= Choice_6_5_7 <= 1 Integer
# 0 <= Choice_6_5_8 <= 1 Integer
# 0 <= Choice_6_5_9 <= 1 Integer
# 0 <= Choice_6_6_1 <= 1 Integer
# 0 <= Choice_6_6_2 <= 1 Integer
# 0 <= Choice_6_6_3 <= 1 Integer
# 0 <= Choice_6_6_4 <= 1 Integer
# 0 <= Choice_6_6_5 <= 1 Integer
# 0 <= Choice_6_6_6 <= 1 Integer
# 0 <= Choice_6_6_7 <= 1 Integer
# 0 <= Choice_6_6_8 <= 1 Integer
# 0 <= Choice_6_6_9 <= 1 Integer
# 0 <= Choice_6_7_1 <= 1 Integer
# 0 <= Choice_6_7_2 <= 1 Integer
# 0 <= Choice_6_7_3 <= 1 Integer
# 0 <= Choice_6_7_4 <= 1 Integer
# 0 <= Choice_6_7_5 <= 1 Integer
# 0 <= Choice_6_7_6 <= 1 Integer
# 0 <= Choice_6_7_7 <= 1 Integer
# 0 <= Choice_6_7_8 <= 1 Integer
# 0 <= Choice_6_7_9 <= 1 Integer
# 0 <= Choice_6_8_1 <= 1 Integer
# 0 <= Choice_6_8_2 <= 1 Integer
# 0 <= Choice_6_8_3 <= 1 Integer
# 0 <= Choice_6_8_4 <= 1 Integer
# 0 <= Choice_6_8_5 <= 1 Integer
# 0 <= Choice_6_8_6 <= 1 Integer
# 0 <= Choice_6_8_7 <= 1 Integer
# 0 <= Choice_6_8_8 <= 1 Integer
# 0 <= Choice_6_8_9 <= 1 Integer
# 0 <= Choice_6_9_1 <= 1 Integer
# 0 <= Choice_6_9_2 <= 1 Integer
# 0 <= Choice_6_9_3 <= 1 Integer
# 0 <= Choice_6_9_4 <= 1 Integer
# 0 <= Choice_6_9_5 <= 1 Integer
# 0 <= Choice_6_9_6 <= 1 Integer
# 0 <= Choice_6_9_7 <= 1 Integer
# 0 <= Choice_6_9_8 <= 1 Integer
# 0 <= Choice_6_9_9 <= 1 Integer
# 0 <= Choice_7_1_1 <= 1 Integer
# 0 <= Choice_7_1_2 <= 1 Integer
# 0 <= Choice_7_1_3 <= 1 Integer
# 0 <= Choice_7_1_4 <= 1 Integer
# 0 <= Choice_7_1_5 <= 1 Integer
# 0 <= Choice_7_1_6 <= 1 Integer
# 0 <= Choice_7_1_7 <= 1 Integer
# 0 <= Choice_7_1_8 <= 1 Integer
# 0 <= Choice_7_1_9 <= 1 Integer
# 0 <= Choice_7_2_1 <= 1 Integer
# 0 <= Choice_7_2_2 <= 1 Integer
# 0 <= Choice_7_2_3 <= 1 Integer
# 0 <= Choice_7_2_4 <= 1 Integer
# 0 <= Choice_7_2_5 <= 1 Integer
# 0 <= Choice_7_2_6 <= 1 Integer
# 0 <= Choice_7_2_7 <= 1 Integer
# 0 <= Choice_7_2_8 <= 1 Integer
# 0 <= Choice_7_2_9 <= 1 Integer
# 0 <= Choice_7_3_1 <= 1 Integer
# 0 <= Choice_7_3_2 <= 1 Integer
# 0 <= Choice_7_3_3 <= 1 Integer
# 0 <= Choice_7_3_4 <= 1 Integer
# 0 <= Choice_7_3_5 <= 1 Integer
# 0 <= Choice_7_3_6 <= 1 Integer
# 0 <= Choice_7_3_7 <= 1 Integer
# 0 <= Choice_7_3_8 <= 1 Integer
# 0 <= Choice_7_3_9 <= 1 Integer
# 0 <= Choice_7_4_1 <= 1 Integer
# 0 <= Choice_7_4_2 <= 1 Integer
# 0 <= Choice_7_4_3 <= 1 Integer
# 0 <= Choice_7_4_4 <= 1 Integer
# 0 <= Choice_7_4_5 <= 1 Integer
# 0 <= Choice_7_4_6 <= 1 Integer
# 0 <= Choice_7_4_7 <= 1 Integer
# 0 <= Choice_7_4_8 <= 1 Integer
# 0 <= Choice_7_4_9 <= 1 Integer
# 0 <= Choice_7_5_1 <= 1 Integer
# 0 <= Choice_7_5_2 <= 1 Integer
# 0 <= Choice_7_5_3 <= 1 Integer
# 0 <= Choice_7_5_4 <= 1 Integer
# 0 <= Choice_7_5_5 <= 1 Integer
# 0 <= Choice_7_5_6 <= 1 Integer
# 0 <= Choice_7_5_7 <= 1 Integer
# 0 <= Choice_7_5_8 <= 1 Integer
# 0 <= Choice_7_5_9 <= 1 Integer
# 0 <= Choice_7_6_1 <= 1 Integer
# 0 <= Choice_7_6_2 <= 1 Integer
# 0 <= Choice_7_6_3 <= 1 Integer
# 0 <= Choice_7_6_4 <= 1 Integer
# 0 <= Choice_7_6_5 <= 1 Integer
# 0 <= Choice_7_6_6 <= 1 Integer
# 0 <= Choice_7_6_7 <= 1 Integer
# 0 <= Choice_7_6_8 <= 1 Integer
# 0 <= Choice_7_6_9 <= 1 Integer
# 0 <= Choice_7_7_1 <= 1 Integer
# 0 <= Choice_7_7_2 <= 1 Integer
# 0 <= Choice_7_7_3 <= 1 Integer
# 0 <= Choice_7_7_4 <= 1 Integer
# 0 <= Choice_7_7_5 <= 1 Integer
# 0 <= Choice_7_7_6 <= 1 Integer
# 0 <= Choice_7_7_7 <= 1 Integer
# 0 <= Choice_7_7_8 <= 1 Integer
# 0 <= Choice_7_7_9 <= 1 Integer
# 0 <= Choice_7_8_1 <= 1 Integer
# 0 <= Choice_7_8_2 <= 1 Integer
# 0 <= Choice_7_8_3 <= 1 Integer
# 0 <= Choice_7_8_4 <= 1 Integer
# 0 <= Choice_7_8_5 <= 1 Integer
# 0 <= Choice_7_8_6 <= 1 Integer
# 0 <= Choice_7_8_7 <= 1 Integer
# 0 <= Choice_7_8_8 <= 1 Integer
# 0 <= Choice_7_8_9 <= 1 Integer
# 0 <= Choice_7_9_1 <= 1 Integer
# 0 <= Choice_7_9_2 <= 1 Integer
# 0 <= Choice_7_9_3 <= 1 Integer
# 0 <= Choice_7_9_4 <= 1 Integer
# 0 <= Choice_7_9_5 <= 1 Integer
# 0 <= Choice_7_9_6 <= 1 Integer
# 0 <= Choice_7_9_7 <= 1 Integer
# 0 <= Choice_7_9_8 <= 1 Integer
# 0 <= Choice_7_9_9 <= 1 Integer
# 0 <= Choice_8_1_1 <= 1 Integer
# 0 <= Choice_8_1_2 <= 1 Integer
# 0 <= Choice_8_1_3 <= 1 Integer
# 0 <= Choice_8_1_4 <= 1 Integer
# 0 <= Choice_8_1_5 <= 1 Integer
# 0 <= Choice_8_1_6 <= 1 Integer
# 0 <= Choice_8_1_7 <= 1 Integer
# 0 <= Choice_8_1_8 <= 1 Integer
# 0 <= Choice_8_1_9 <= 1 Integer
# 0 <= Choice_8_2_1 <= 1 Integer
# 0 <= Choice_8_2_2 <= 1 Integer
# 0 <= Choice_8_2_3 <= 1 Integer
# 0 <= Choice_8_2_4 <= 1 Integer
# 0 <= Choice_8_2_5 <= 1 Integer
# 0 <= Choice_8_2_6 <= 1 Integer
# 0 <= Choice_8_2_7 <= 1 Integer
# 0 <= Choice_8_2_8 <= 1 Integer
# 0 <= Choice_8_2_9 <= 1 Integer
# 0 <= Choice_8_3_1 <= 1 Integer
# 0 <= Choice_8_3_2 <= 1 Integer
# 0 <= Choice_8_3_3 <= 1 Integer
# 0 <= Choice_8_3_4 <= 1 Integer
# 0 <= Choice_8_3_5 <= 1 Integer
# 0 <= Choice_8_3_6 <= 1 Integer
# 0 <= Choice_8_3_7 <= 1 Integer
# 0 <= Choice_8_3_8 <= 1 Integer
# 0 <= Choice_8_3_9 <= 1 Integer
# 0 <= Choice_8_4_1 <= 1 Integer
# 0 <= Choice_8_4_2 <= 1 Integer
# 0 <= Choice_8_4_3 <= 1 Integer
# 0 <= Choice_8_4_4 <= 1 Integer
# 0 <= Choice_8_4_5 <= 1 Integer
# 0 <= Choice_8_4_6 <= 1 Integer
# 0 <= Choice_8_4_7 <= 1 Integer
# 0 <= Choice_8_4_8 <= 1 Integer
# 0 <= Choice_8_4_9 <= 1 Integer
# 0 <= Choice_8_5_1 <= 1 Integer
# 0 <= Choice_8_5_2 <= 1 Integer
# 0 <= Choice_8_5_3 <= 1 Integer
# 0 <= Choice_8_5_4 <= 1 Integer
# 0 <= Choice_8_5_5 <= 1 Integer
# 0 <= Choice_8_5_6 <= 1 Integer
# 0 <= Choice_8_5_7 <= 1 Integer
# 0 <= Choice_8_5_8 <= 1 Integer
# 0 <= Choice_8_5_9 <= 1 Integer
# 0 <= Choice_8_6_1 <= 1 Integer
# 0 <= Choice_8_6_2 <= 1 Integer
# 0 <= Choice_8_6_3 <= 1 Integer
# 0 <= Choice_8_6_4 <= 1 Integer
# 0 <= Choice_8_6_5 <= 1 Integer
# 0 <= Choice_8_6_6 <= 1 Integer
# 0 <= Choice_8_6_7 <= 1 Integer
# 0 <= Choice_8_6_8 <= 1 Integer
# 0 <= Choice_8_6_9 <= 1 Integer
# 0 <= Choice_8_7_1 <= 1 Integer
# 0 <= Choice_8_7_2 <= 1 Integer
# 0 <= Choice_8_7_3 <= 1 Integer
# 0 <= Choice_8_7_4 <= 1 Integer
# 0 <= Choice_8_7_5 <= 1 Integer
# 0 <= Choice_8_7_6 <= 1 Integer
# 0 <= Choice_8_7_7 <= 1 Integer
# 0 <= Choice_8_7_8 <= 1 Integer
# 0 <= Choice_8_7_9 <= 1 Integer
# 0 <= Choice_8_8_1 <= 1 Integer
# 0 <= Choice_8_8_2 <= 1 Integer
# 0 <= Choice_8_8_3 <= 1 Integer
# 0 <= Choice_8_8_4 <= 1 Integer
# 0 <= Choice_8_8_5 <= 1 Integer
# 0 <= Choice_8_8_6 <= 1 Integer
# 0 <= Choice_8_8_7 <= 1 Integer
# 0 <= Choice_8_8_8 <= 1 Integer
# 0 <= Choice_8_8_9 <= 1 Integer
# 0 <= Choice_8_9_1 <= 1 Integer
# 0 <= Choice_8_9_2 <= 1 Integer
# 0 <= Choice_8_9_3 <= 1 Integer
# 0 <= Choice_8_9_4 <= 1 Integer
# 0 <= Choice_8_9_5 <= 1 Integer
# 0 <= Choice_8_9_6 <= 1 Integer
# 0 <= Choice_8_9_7 <= 1 Integer
# 0 <= Choice_8_9_8 <= 1 Integer
# 0 <= Choice_8_9_9 <= 1 Integer
# 0 <= Choice_9_1_1 <= 1 Integer
# 0 <= Choice_9_1_2 <= 1 Integer
# 0 <= Choice_9_1_3 <= 1 Integer
# 0 <= Choice_9_1_4 <= 1 Integer
# 0 <= Choice_9_1_5 <= 1 Integer
# 0 <= Choice_9_1_6 <= 1 Integer
# 0 <= Choice_9_1_7 <= 1 Integer
# 0 <= Choice_9_1_8 <= 1 Integer
# 0 <= Choice_9_1_9 <= 1 Integer
# 0 <= Choice_9_2_1 <= 1 Integer
# 0 <= Choice_9_2_2 <= 1 Integer
# 0 <= Choice_9_2_3 <= 1 Integer
# 0 <= Choice_9_2_4 <= 1 Integer
# 0 <= Choice_9_2_5 <= 1 Integer
# 0 <= Choice_9_2_6 <= 1 Integer
# 0 <= Choice_9_2_7 <= 1 Integer
# 0 <= Choice_9_2_8 <= 1 Integer
# 0 <= Choice_9_2_9 <= 1 Integer
# 0 <= Choice_9_3_1 <= 1 Integer
# 0 <= Choice_9_3_2 <= 1 Integer
# 0 <= Choice_9_3_3 <= 1 Integer
# 0 <= Choice_9_3_4 <= 1 Integer
# 0 <= Choice_9_3_5 <= 1 Integer
# 0 <= Choice_9_3_6 <= 1 Integer
# 0 <= Choice_9_3_7 <= 1 Integer
# 0 <= Choice_9_3_8 <= 1 Integer
# 0 <= Choice_9_3_9 <= 1 Integer
# 0 <= Choice_9_4_1 <= 1 Integer
# 0 <= Choice_9_4_2 <= 1 Integer
# 0 <= Choice_9_4_3 <= 1 Integer
# 0 <= Choice_9_4_4 <= 1 Integer
# 0 <= Choice_9_4_5 <= 1 Integer
# 0 <= Choice_9_4_6 <= 1 Integer
# 0 <= Choice_9_4_7 <= 1 Integer
# 0 <= Choice_9_4_8 <= 1 Integer
# 0 <= Choice_9_4_9 <= 1 Integer
# 0 <= Choice_9_5_1 <= 1 Integer
# 0 <= Choice_9_5_2 <= 1 Integer
# 0 <= Choice_9_5_3 <= 1 Integer
# 0 <= Choice_9_5_4 <= 1 Integer
# 0 <= Choice_9_5_5 <= 1 Integer
# 0 <= Choice_9_5_6 <= 1 Integer
# 0 <= Choice_9_5_7 <= 1 Integer
# 0 <= Choice_9_5_8 <= 1 Integer
# 0 <= Choice_9_5_9 <= 1 Integer
# 0 <= Choice_9_6_1 <= 1 Integer
# 0 <= Choice_9_6_2 <= 1 Integer
# 0 <= Choice_9_6_3 <= 1 Integer
# 0 <= Choice_9_6_4 <= 1 Integer
# 0 <= Choice_9_6_5 <= 1 Integer
# 0 <= Choice_9_6_6 <= 1 Integer
# 0 <= Choice_9_6_7 <= 1 Integer
# 0 <= Choice_9_6_8 <= 1 Integer
# 0 <= Choice_9_6_9 <= 1 Integer
# 0 <= Choice_9_7_1 <= 1 Integer
# 0 <= Choice_9_7_2 <= 1 Integer
# 0 <= Choice_9_7_3 <= 1 Integer
# 0 <= Choice_9_7_4 <= 1 Integer
# 0 <= Choice_9_7_5 <= 1 Integer
# 0 <= Choice_9_7_6 <= 1 Integer
# 0 <= Choice_9_7_7 <= 1 Integer
# 0 <= Choice_9_7_8 <= 1 Integer
# 0 <= Choice_9_7_9 <= 1 Integer
# 0 <= Choice_9_8_1 <= 1 Integer
# 0 <= Choice_9_8_2 <= 1 Integer
# 0 <= Choice_9_8_3 <= 1 Integer
# 0 <= Choice_9_8_4 <= 1 Integer
# 0 <= Choice_9_8_5 <= 1 Integer
# 0 <= Choice_9_8_6 <= 1 Integer
# 0 <= Choice_9_8_7 <= 1 Integer
# 0 <= Choice_9_8_8 <= 1 Integer
# 0 <= Choice_9_8_9 <= 1 Integer
# 0 <= Choice_9_9_1 <= 1 Integer
# 0 <= Choice_9_9_2 <= 1 Integer
# 0 <= Choice_9_9_3 <= 1 Integer
# 0 <= Choice_9_9_4 <= 1 Integer
# 0 <= Choice_9_9_5 <= 1 Integer
# 0 <= Choice_9_9_6 <= 1 Integer
# 0 <= Choice_9_9_7 <= 1 Integer
# 0 <= Choice_9_9_8 <= 1 Integer
# 0 <= Choice_9_9_9 <= 1 Integer

# %%
prob.solve()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/conda/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/48c0c2087b764d7e8f4c6b51d0436d30-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/48c0c2087b764d7e8f4c6b51d0436d30-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 358 COLUMNS
# At line 4763 RHS
# At line 5117 BOUNDS
# At line 5848 ENDATA
# Problem MODEL has 353 rows, 730 columns and 2945 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
# 1

# %%
# The status of the solution is printed to the screen
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# The solution is printed to the console
for r in ROWS:
    if r in [1, 4, 7]:
        print("+-------+-------+-------+")
    for c in COLS:
        for v in VALS:
            if value(choices[v][r][c]) == 1:
                if c in [1, 4, 7]:
                    print("|", end=" ")
                print(v, end=" ")
                if c == 9:
                    print("|")
print("+-------+-------+-------+")
# Out:
# +-------+-------+-------+
# | 5 3 4 | 6 7 8 | 9 1 2 |
# | 6 7 2 | 1 9 5 | 3 4 8 |
# | 1 9 8 | 3 4 2 | 5 6 7 |
# +-------+-------+-------+
# | 8 5 9 | 7 6 1 | 4 2 3 |
# | 4 2 6 | 8 5 3 | 7 9 1 |
# | 7 1 3 | 9 2 4 | 8 5 6 |
# +-------+-------+-------+
# | 9 6 1 | 5 3 7 | 2 8 4 |
# | 2 8 7 | 4 1 9 | 6 3 5 |
# | 3 4 5 | 2 8 6 | 1 7 9 |
# +-------+-------+-------+

# %% [markdown]
# ## Resources

# %% [markdown]
# - https://benalexkeen.com/linear-programming-with-python-and-pulp-part-5/
# - https://coin-or.github.io/pulp/CaseStudies/a_sudoku_problem.html
# - https://en.wikipedia.org/wiki/Knapsack_problem
# - https://slama.dev/youtube/linear-programming-in-python/#partition-problem
